# %%
txt = open('17.txt','r')
listik = []
mass = (x for x in txt)
for num in mass:
    listik.append(int(num))

# %%
listik
# Out:
# [-67,
#  -694,
#  835,
#  786,
#  -457,
#  495,
#  -699,
#  -592,
#  -405,
#  -745,
#  656,
#  501,
#  48,
#  856,
#  417,
#  -600,
#  521,
#  221,
#  -548,
#  -421,
#  -139,
#  -293,
#  -313,
#  662,
#  995,
#  -855,
#  -228,
#  -333,
#  820,
#  132,
#  78,
#  -927,
#  -953,
#  -381,
#  -758,
#  661,
#  805,
#  -785,
#  -526,
#  778,
#  -83,
#  -62,
#  911,
#  -300,
#  749,
#  -954,
#  -781,
#  -431,
#  802,
#  734,
#  929,
#  -216,
#  -159,
#  -925,
#  -668,
#  26,
#  -248,
#  598,
#  829,
#  189,
#  133,
#  702,
#  956,
#  108,
#  -369,
#  210,
#  10,
#  30,
#  -687,
#  -380,
#  226,
#  -555,
#  -135,
#  -471,
#  95,
#  -217,
#  -755,
#  -272,
#  309,
#  885,
#  92,
#  -208,
#  -468,
#  -434,
#  -270,
#  315,
#  -103,
#  -774,
#  -183,
#  737,
#  -420,
#  175,
#  -987,
#  597,
#  -549,
#  -314,
#  -293,
#  997,
#  -781,
#  959,
#  435,
#  142,
#  -398,
#  -938,
#  480,
#  354,
#  557,
#  -406,
#  -822,
#  262,
#  -713,
#  259,
#  631,
#  444,
#  -106,
#  -578,
#  -884,
#  440,
# ...

# %%
mahs = []
for i in range(len(listik)-1):
    if listik[i]%3 == 0 or listik[i+1]%3 == 0:
        mahs.append(listik[i] + listik[i+1])
