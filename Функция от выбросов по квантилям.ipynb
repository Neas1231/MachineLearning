# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter("default")

# %%
df = pd.read_csv(r"C:\Users\nicka\Downloads\archive\winemag-data_first150k.csv",sep = ',')

# %%
df.sample(10)
# Out:
#         Unnamed: 0    country  \
# 44411        44411      Spain
# 115314      115314    Germany
# 64022        64022  Australia
# 142138      142138     France
# 120169      120169         US
# 88274        88274         US
# 130481      130481         US
# 105651      105651   Portugal
# 140987      140987         US
# 53940        53940         US
#
#                                               description  \
# 44411   Earthy, baked, raisiny aromas convey ripeness ...
# 115314  A step up from the 2003 offerings from this es...
# 64022   A sweet attack of ripe fruit is the opener for...
# 142138  87-89 Barrel sample. There are very ripe fruit...
# 120169  Firm, spicy and loaded with generous tropical ...
# 88274   Sourced from the Dineen Vineyard in the Rattle...
# 130481  Franciscan helped pioneer the use of wild or i...
# 105651  A blend of Roupeiro, Perrum and Antão Vaz, thi...
# 140987  Dark and thick in the way of Malbec, this is b...
# ...

# %%
df = pd.read_csv(r'C:\Users\nicka\Downloads\adult.csv',names = ['workclass','finalweigt','education','education-num','marital-status',
                                                                 'occupation','relationship','race','sex','capital-loss',
                                                                'capital-gain','age','native-country','hours-per-week'])

# %%
df.reset_index(drop = True,inplace = True)

# %%
df
# Out:
#                workclass  finalweigt    education  education-num  \
# 0              State-gov       77516    Bachelors             13
# 1       Self-emp-not-inc       83311    Bachelors             13
# 2                Private      215646      HS-grad              9
# 3                Private      234721         11th              7
# 4                Private      338409    Bachelors             13
# ...                  ...         ...          ...            ...
# 32556            Private      257302   Assoc-acdm             12
# 32557            Private      154374      HS-grad              9
# 32558            Private      151910      HS-grad              9
# 32559            Private      201490      HS-grad              9
# 32560       Self-emp-inc      287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.sample(10)
# Out:
#                workclass  finalweigt      education  education-num  \
# 24137          Local-gov      273402        7th-8th              4
# 6327             Private      211527      Bachelors             13
# 2925             Private      101320     Assoc-acdm             12
# 7267             Private      405177           10th              6
# 16533            Private      212522        HS-grad              9
# 3477             Private      503923        HS-grad              9
# 5108        Self-emp-inc      187720   Some-college             10
# 27432            Private       35724    Prof-school             15
# 26130   Self-emp-not-inc       46704        Masters             14
# 17779            Private      250743   Some-college             10
#
#             marital-status          occupation     relationship    race  \
# 24137   Married-civ-spouse    Transport-moving          Husband   White
# 6327         Never-married        Adm-clerical    Not-in-family   White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   workclass       32561 non-null  object
#  1   finalweigt      32561 non-null  int64
#  2   education       32561 non-null  object
#  3   education-num   32561 non-null  int64
#  4   marital-status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   capital-loss    32561 non-null  int64
#  10  capital-gain    32561 non-null  int64
#  11  age             32561 non-null  int64
#  12  native-country  32561 non-null  object
#  13  hours-per-week  32561 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.5+ MB

# %%
df.describe()
# Out:
#          finalweigt  education-num  capital-loss  capital-gain           age
# count  3.256100e+04   32561.000000  32561.000000  32561.000000  32561.000000
# mean   1.897784e+05      10.080679   1077.648844     87.303830     40.437456
# std    1.055500e+05       2.572720   7385.292085    402.960219     12.347429
# min    1.228500e+04       1.000000      0.000000      0.000000      1.000000
# 25%    1.178270e+05       9.000000      0.000000      0.000000     40.000000
# 50%    1.783560e+05      10.000000      0.000000      0.000000     40.000000
# 75%    2.370510e+05      12.000000      0.000000      0.000000     45.000000
# max    1.484705e+06      16.000000  99999.000000   4356.000000     99.000000

# %%
print(df.shape)
df.dtypes
# Out:
# (32561, 14)
# workclass         object
# finalweigt         int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-loss       int64
# capital-gain       int64
# age                int64
# native-country    object
# hours-per-week    object
# dtype: object

# %%
plt.figure(figsize = [12,12])
sns.boxplot(df)
# Out:
# <Axes: >

# %%
def quantiles(arr):
    work_val = arr.copy()
    Q1 = work_val.quantile(0.25)#np.percentile(work_val, 25, method= 'midpoint')
    Q3 = work_val.quantile(0.75)#np.percentile(work_val, 75, method= 'midpoint')
    IQR = Q3-Q1
    upper = Q3+1.5*IQR
    lower = Q1-1.5*IQR
    return upper,lower

def anti_emmi(df):
    if df.select_dtypes(include = [np.number]).all().any():
        for col in df.select_dtypes(include = [np.number]).columns:
            
            up,low = quantiles(df[col])
            df = df[~(df[col] < low) & ~(df[col] > up)]

    return df.reset_index(drop=True)

# %%
df_copy = anti_emmi(df)
df_copy
# Out:
#            workclass  finalweigt      education  education-num  \
# 0          State-gov       77516      Bachelors             13
# 1            Private      215646        HS-grad              9
# 2            Private      234721           11th              7
# 3            Private      338409      Bachelors             13
# 4            Private      284582        Masters             14
# ...              ...         ...            ...            ...
# 26084        Private      310152   Some-college             10
# 26085        Private      257302     Assoc-acdm             12
# 26086        Private      154374        HS-grad              9
# 26087        Private      151910        HS-grad              9
# 26088   Self-emp-inc      287927        HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...
