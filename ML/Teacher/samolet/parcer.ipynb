# %%
import cianparser

data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location = "Москва",
    rooms=1,
    is_saving_csv=True,
    is_latin=False,
    is_express_mode=False,
)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_moskva_07_Jan_2024_05_08_02_980059.csv
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=1&offer_type=flat&deal_type=sale&room1=1&with_neighbors=0
# Collecting information from pages with list of announcements
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 41 610 879 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 2 %. Average price: 33 372 181 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 3 %. Average price: 31 233 918 rub
#  4 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 112. Progress ratio: 4 %. Average price: 29 289 868 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 140. Progress ratio: 5 %. Average price: 26 509 567 rub
#  6 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 168. Progress ratio: 6 %. Average price: 24 492 951 rub
#  7 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 196. Progress ratio: 7 %. Average price: 23 090 887 rub
#  8 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 224. Progress ratio: 8 %. Average price: 24 027 647 rub
#  9 | 9 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 252. Progress ratio: 9 %. Average price: 24 132 087 rub
#  10 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 280. Progress ratio: 10 %. Average price: 26 499 758 rub
#  11 | 11 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 308. Progress ratio: 11 %. Average price: 27 844 248 rub
#  12 | 12 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 336. Progress ratio: 12 %. Average price: 29 087 074 rub
#  13 | 13 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 364. Progress ratio: 13 %. Average price: 28 398 108 rub
#  14 | 14 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 392. Progress ratio: 14 %. Average price: 27 914 719 rub
#  15 | 15 page with list: [=>=>=>=>=>=>=>                                          ] 25% | Count of all parsed: 399. Progress ratio: 15 %. Average price: 27 717 598 rub
#  15 | 15 page with list: [=>=>=>=>=>=>                                            ] 22% | Count of all parsed: 406. Progress ratio: 15 %. Average price: 27 523 753 rub
#  15 | 15 page with list: [=>=>=>=>=>=>=>=>=>                                      ] 33% | Count of all parsed: 416. Progress ratio: 15 %. Average price: 27 344 172 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 15 page...
#
# Average price per day: 27 344 546 rub
#
#  16 page: 28 offers
#  16 | 16 page with list: [=>                                                      ] 4% | Count of all parsed: 419. Progress ratio: 15 %. Average price: 27 258 891 rub
#  16 | 16 page with list: [=>=>                                                    ] 8% | Count of all parsed: 422. Progress ratio: 16 %. Average price: 27 132 122 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 16 page...
#
# Average price per day: 27 090 496 rub
#
#  17 page: 28 offers
#  17 | 17 page with list: [=>                                                      ] 4% | Count of all parsed: 425. Progress ratio: 16 %. Average price: 27 010 070 rub
#  17 | 17 page with list: [=>=>                                                    ] 8% | Count of all parsed: 428. Progress ratio: 16 %. Average price: 26 891 309 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 17 page...
#
# Average price per day: 26 852 153 rub
#
#  18 page: 28 offers
#  18 | 18 page with list: [=>                                                      ] 4% | Count of all parsed: 431. Progress ratio: 16 %. Average price: 26 776 737 rub
#  18 | 18 page with list: [=>=>                                                    ] 8% | Count of all parsed: 434. Progress ratio: 16 %. Average price: 26 665 450 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 18 page...
#
# Average price per day: 26 628 852 rub
#
#  19 page: 28 offers
#  19 | 19 page with list: [=>                                                      ] 4% | Count of all parsed: 437. Progress ratio: 16 %. Average price: 26 558 698 rub
#  19 | 19 page with list: [=>=>                                                    ] 8% | Count of all parsed: 440. Progress ratio: 16 %. Average price: 26 454 764 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 19 page...
#
# Average price per day: 26 420 626 rub
#
#  20 page: 28 offers
#  20 | 20 page with list: [=>                                                      ] 4% | Count of all parsed: 443. Progress ratio: 16 %. Average price: 26 354 619 rub
#  20 | 20 page with list: [=>=>                                                    ] 8% | Count of all parsed: 446. Progress ratio: 16 %. Average price: 26 256 718 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 20 page...
#
# Average price per day: 26 224 600 rub
#
#  21 page: 28 offers
#  21 | 21 page with list: [=>                                                      ] 4% | Count of all parsed: 449. Progress ratio: 17 %. Average price: 26 163 546 rub
#  21 | 21 page with list: [=>=>                                                    ] 8% | Count of all parsed: 452. Progress ratio: 17 %. Average price: 26 073 121 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 21 page...
#
# Average price per day: 26 043 311 rub
#
#  22 page: 28 offers
#  22 | 22 page with list: [=>                                                      ] 4% | Count of all parsed: 455. Progress ratio: 17 %. Average price: 25 987 198 rub
#  22 | 22 page with list: [=>=>                                                    ] 8% | Count of all parsed: 458. Progress ratio: 17 %. Average price: 25 903 609 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 22 page...
#
# Average price per day: 25 875 932 rub
#
#  23 page: 28 offers
#  23 | 23 page with list: [=>                                                      ] 4% | Count of all parsed: 461. Progress ratio: 17 %. Average price: 25 823 542 rub
#  23 | 23 page with list: [=>=>                                                    ] 8% | Count of all parsed: 464. Progress ratio: 17 %. Average price: 25 747 078 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 23 page...
#
# Average price per day: 25 721 708 rub
#
#  24 page: 28 offers
#  24 | 24 page with list: [=>                                                      ] 4% | Count of all parsed: 467. Progress ratio: 17 %. Average price: 25 674 934 rub
#  24 | 24 page with list: [=>=>                                                    ] 8% | Count of all parsed: 470. Progress ratio: 17 %. Average price: 25 606 421 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 24 page...
#
# Average price per day: 25 583 846 rub
#
#  25 page: 28 offers
#  25 | 25 page with list: [=>                                                      ] 4% | Count of all parsed: 473. Progress ratio: 17 %. Average price: 25 543 323 rub
#  25 | 25 page with list: [=>=>                                                    ] 8% | Count of all parsed: 476. Progress ratio: 17 %. Average price: 25 483 214 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 25 page...
#
# Average price per day: 25 463 334 rub
#
#  26 page: 28 offers
#  26 | 26 page with list: [=>                                                      ] 4% | Count of all parsed: 479. Progress ratio: 18 %. Average price: 25 428 038 rub
#  26 | 26 page with list: [=>=>                                                    ] 8% | Count of all parsed: 482. Progress ratio: 18 %. Average price: 25 375 664 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 26 page...
#
# Average price per day: 25 358 220 rub
#
#  27 page: 28 offers
#  27 | 27 page with list: [=>                                                      ] 4% | Count of all parsed: 485. Progress ratio: 18 %. Average price: 25 327 464 rub
#  27 | 27 page with list: [=>=>                                                    ] 8% | Count of all parsed: 488. Progress ratio: 18 %. Average price: 25 283 109 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 27 page...
#
# Average price per day: 25 268 785 rub
#
#  28 page: 28 offers
#  28 | 28 page with list: [=>                                                      ] 4% | Count of all parsed: 491. Progress ratio: 18 %. Average price: 25 245 675 rub
#  28 | 28 page with list: [=>=>                                                    ] 8% | Count of all parsed: 494. Progress ratio: 18 %. Average price: 25 210 660 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 28 page...
#
# Average price per day: 25 199 164 rub
#
#  29 page: 28 offers
#  29 | 29 page with list: [=>                                                      ] 4% | Count of all parsed: 497. Progress ratio: 18 %. Average price: 25 181 461 rub
#  29 | 29 page with list: [=>=>                                                    ] 8% | Count of all parsed: 500. Progress ratio: 18 %. Average price: 25 156 102 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 29 page...
#
# Average price per day: 25 148 135 rub
#
#  30 | 30 page with list: [=>                                                      ] 4% | Count of all parsed: 502. Progress ratio: 18 %. Average price: 25 142 336 rub
#  30 | 30 page with list: [=>=>                                                    ] 8% | Count of all parsed: 505. Progress ratio: 19 %. Average price: 25 124 535 rub
#  30 | 30 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 509. Progress ratio: 19 %. Average price: 25 102 296 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 30 page...
#
# Average price per day: 25 097 478 rub
#
#  31 | 31 page with list: [=>                                                      ] 4% | Count of all parsed: 511. Progress ratio: 19 %. Average price: 25 097 961 rub
#  31 | 31 page with list: [=>=>                                                    ] 8% | Count of all parsed: 514. Progress ratio: 19 %. Average price: 25 099 998 rub
#  31 | 31 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 518. Progress ratio: 19 %. Average price: 25 102 783 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 31 page...
#
# Average price per day: 25 104 319 rub
#
#  32 page: 28 offers
#  32 | 32 page with list: [=>                                                      ] 4% | Count of all parsed: 521. Progress ratio: 19 %. Average price: 25 146 912 rub
#  32 | 32 page with list: [=>=>                                                    ] 8% | Count of all parsed: 524. Progress ratio: 19 %. Average price: 25 212 115 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 32 page...
#
# Average price per day: 25 233 614 rub
#
#  33 page: 28 offers
#  33 | 33 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 529. Progress ratio: 19 %. Average price: 26 158 031 rub
#  33 | 33 page with list: [=>=>=>=>                                                ] 15% | Count of all parsed: 534. Progress ratio: 20 %. Average price: 27 374 183 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 33 page...
#
# Average price per day: 27 657 884 rub
#
#  34 page: 28 offers
#  34 | 34 page with list: [=>                                                      ] 4% | Count of all parsed: 537. Progress ratio: 20 %. Average price: 27 576 871 rub
#  34 | 34 page with list: [=>=>                                                    ] 8% | Count of all parsed: 540. Progress ratio: 20 %. Average price: 27 456 972 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 34 page...
#
# Average price per day: 27 417 376 rub
#
#  35 page: 28 offers
#  35 | 35 page with list: [=>                                                      ] 4% | Count of all parsed: 543. Progress ratio: 20 %. Average price: 27 341 055 rub
#  35 | 35 page with list: [=>=>                                                    ] 8% | Count of all parsed: 546. Progress ratio: 20 %. Average price: 27 227 625 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 35 page...
#
# Average price per day: 27 190 142 rub
#
#  36 page: 28 offers
#  36 | 36 page with list: [=>                                                      ] 4% | Count of all parsed: 549. Progress ratio: 20 %. Average price: 27 117 059 rub
#  36 | 36 page with list: [=>=>                                                    ] 8% | Count of all parsed: 552. Progress ratio: 20 %. Average price: 27 008 589 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 36 page...
#
# Average price per day: 26 972 824 rub
#
#  37 page: 28 offers
#  37 | 37 page with list: [=>                                                      ] 4% | Count of all parsed: 555. Progress ratio: 20 %. Average price: 26 902 387 rub
#  37 | 37 page with list: [=>=>                                                    ] 8% | Count of all parsed: 558. Progress ratio: 20 %. Average price: 26 797 836 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 37 page...
#
# Average price per day: 26 763 280 rub
#
#  38 page: 28 offers
#  38 | 38 page with list: [=>                                                      ] 4% | Count of all parsed: 561. Progress ratio: 21 %. Average price: 26 695 699 rub
#  38 | 38 page with list: [=>=>                                                    ] 8% | Count of all parsed: 564. Progress ratio: 21 %. Average price: 26 595 093 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 38 page...
#
# Average price per day: 26 561 756 rub
#
#  39 page: 28 offers
#  39 | 39 page with list: [=>                                                      ] 4% | Count of all parsed: 567. Progress ratio: 21 %. Average price: 26 496 279 rub
#  39 | 39 page with list: [=>=>                                                    ] 8% | Count of all parsed: 570. Progress ratio: 21 %. Average price: 26 398 803 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 39 page...
#
# Average price per day: 26 366 501 rub
#
#  40 page: 28 offers
#  40 | 40 page with list: [=>                                                      ] 4% | Count of all parsed: 573. Progress ratio: 21 %. Average price: 26 303 099 rub
#  40 | 40 page with list: [=>=>                                                    ] 8% | Count of all parsed: 576. Progress ratio: 21 %. Average price: 26 209 156 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 40 page...
#
# Average price per day: 26 178 065 rub
#
#  41 page: 28 offers
#  41 | 41 page with list: [=>                                                      ] 4% | Count of all parsed: 579. Progress ratio: 21 %. Average price: 26 116 412 rub
#  41 | 41 page with list: [=>=>                                                    ] 8% | Count of all parsed: 582. Progress ratio: 21 %. Average price: 26 024 935 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 41 page...
#
# Average price per day: 25 994 544 rub
#
#  42 page: 28 offers
#  42 | 42 page with list: [=>                                                      ] 4% | Count of all parsed: 585. Progress ratio: 21 %. Average price: 25 934 786 rub
#  42 | 42 page with list: [=>=>                                                    ] 8% | Count of all parsed: 588. Progress ratio: 21 %. Average price: 25 846 005 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 42 page...
#
# Average price per day: 25 816 597 rub
#
#  43 page: 28 offers
#  43 | 43 page with list: [=>                                                      ] 4% | Count of all parsed: 591. Progress ratio: 22 %. Average price: 25 758 766 rub
#  43 | 43 page with list: [=>=>                                                    ] 8% | Count of all parsed: 594. Progress ratio: 22 %. Average price: 25 672 793 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 43 page...
#
# Average price per day: 25 644 251 rub
#
#  44 page: 28 offers
#  44 | 44 page with list: [=>                                                      ] 4% | Count of all parsed: 597. Progress ratio: 22 %. Average price: 25 588 087 rub
#  44 | 44 page with list: [=>=>                                                    ] 8% | Count of all parsed: 600. Progress ratio: 22 %. Average price: 25 504 324 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 44 page...
#
# Average price per day: 25 476 529 rub
#
#  45 page: 28 offers
#  45 | 45 page with list: [=>                                                      ] 4% | Count of all parsed: 603. Progress ratio: 22 %. Average price: 25 421 848 rub
#  45 | 45 page with list: [=>=>                                                    ] 8% | Count of all parsed: 606. Progress ratio: 22 %. Average price: 25 340 506 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 45 page...
#
# Average price per day: 25 313 528 rub
#
#  46 page: 28 offers
#  46 | 46 page with list: [=>                                                      ] 4% | Count of all parsed: 609. Progress ratio: 22 %. Average price: 25 260 489 rub
#  46 | 46 page with list: [=>=>                                                    ] 8% | Count of all parsed: 612. Progress ratio: 22 %. Average price: 25 181 408 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 46 page...
#
# Average price per day: 25 155 216 rub
#
#  47 page: 28 offers
#  47 | 47 page with list: [=>                                                      ] 4% | Count of all parsed: 615. Progress ratio: 22 %. Average price: 25 103 814 rub
#  47 page: 28 offers
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 47 page...
#
# Average price per day: 25 052 463 rub
#
#  48 page: 28 offers
#  48 | 48 page with list: [=>                                                      ] 4% | Count of all parsed: 619. Progress ratio: 23 %. Average price: 25 002 297 rub
#  48 | 48 page with list: [=>=>                                                    ] 8% | Count of all parsed: 622. Progress ratio: 23 %. Average price: 24 927 602 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 48 page...
#
# Average price per day: 24 902 878 rub
#
#  49 page: 28 offers
#  49 | 49 page with list: [=>                                                      ] 4% | Count of all parsed: 625. Progress ratio: 23 %. Average price: 24 854 290 rub
#  49 | 49 page with list: [=>=>                                                    ] 8% | Count of all parsed: 628. Progress ratio: 23 %. Average price: 24 782 037 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 49 page...
#
# Average price per day: 24 758 052 rub
#
#  50 page: 28 offers
#  50 | 50 page with list: [=>                                                      ] 4% | Count of all parsed: 631. Progress ratio: 23 %. Average price: 24 711 038 rub
#  50 | 50 page with list: [=>=>                                                    ] 8% | Count of all parsed: 634. Progress ratio: 23 %. Average price: 24 640 852 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 50 page...
#
# Average price per day: 24 617 657 rub
#
#  51 page: 28 offers
#  51 | 51 page with list: [=>                                                      ] 4% | Count of all parsed: 637. Progress ratio: 23 %. Average price: 24 572 212 rub
#  51 | 51 page with list: [=>=>                                                    ] 8% | Count of all parsed: 640. Progress ratio: 23 %. Average price: 24 504 448 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 51 page...
#
# Average price per day: 24 482 036 rub
#
#  52 page: 28 offers
#  52 | 52 page with list: [=>                                                      ] 4% | Count of all parsed: 643. Progress ratio: 23 %. Average price: 24 437 827 rub
#  52 | 52 page with list: [=>=>                                                    ] 8% | Count of all parsed: 646. Progress ratio: 24 %. Average price: 24 372 277 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 52 page...
#
# Average price per day: 24 350 498 rub
#
#  53 page: 28 offers
#  53 | 53 page with list: [=>                                                      ] 4% | Count of all parsed: 649. Progress ratio: 24 %. Average price: 24 307 862 rub
#  53 | 53 page with list: [=>=>                                                    ] 8% | Count of all parsed: 652. Progress ratio: 24 %. Average price: 24 244 246 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 53 page...
#
# Average price per day: 24 223 244 rub
#
#  54 page: 25 offers
#  54 | 54 page with list: [=>                                                ] 4% | Count of all parsed: 655. Progress ratio: 27 %. Average price: 24 182 034 rub
#  54 | 54 page with list: [=>=>                                              ] 8% | Count of all parsed: 658. Progress ratio: 27 %. Average price: 24 120 607 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 239: character maps to <undefined>
# The collection of information from the pages with ending parse on 54 page...
#
# Average price per day: 24 100 242 rub
#
#  55 | 55 page: cian is redirecting from page 55 to page 1... there is maximum value of page, you should try to decrease number of page... ending...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 659. Average price: 24 100 242 rub

# %%
data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location = "Москва",
    rooms=2,
    is_saving_csv=True,
    is_latin=False,
    is_express_mode=False,
)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_moskva_07_Jan_2024_05_52_56_834447.csv
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=1&offer_type=flat&deal_type=sale&room2=1&with_neighbors=0
# Collecting information from pages with list of announcements
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 79 925 934 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 2 %. Average price: 63 416 240 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 3 %. Average price: 54 470 341 rub
#  4 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 112. Progress ratio: 4 %. Average price: 57 393 912 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 140. Progress ratio: 5 %. Average price: 56 348 891 rub
#  6 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 168. Progress ratio: 6 %. Average price: 51 033 688 rub
#  7 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 196. Progress ratio: 7 %. Average price: 46 592 152 rub
#  8 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 224. Progress ratio: 8 %. Average price: 44 015 683 rub
#  9 | 9 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 252. Progress ratio: 9 %. Average price: 43 637 025 rub
#  10 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 280. Progress ratio: 10 %. Average price: 44 200 476 rub
#  11 | 11 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 308. Progress ratio: 11 %. Average price: 44 050 142 rub
#  12 | 12 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 336. Progress ratio: 12 %. Average price: 44 575 632 rub
#  13 | 13 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 364. Progress ratio: 13 %. Average price: 46 460 187 rub
#  14 | 14 page with list: [=>=>=>=>=>                                              ] 18% | Count of all parsed: 369. Progress ratio: 14 %. Average price: 47 424 796 rub
#  14 | 14 page with list: [=>=>=>=>=>=>                                            ] 22% | Count of all parsed: 376. Progress ratio: 14 %. Average price: 48 991 466 rub
#  14 | 14 page with list: [=>=>=>=>=>=>=>                                          ] 25% | Count of all parsed: 384. Progress ratio: 14 %. Average price: 50 050 589 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 14 page...
#
# Average price per day: 49 980 587 rub
#
#  15 page: 28 offers
#  15 | 15 page with list: [=>                                                      ] 4% | Count of all parsed: 387. Progress ratio: 14 %. Average price: 50 970 300 rub
#  15 | 15 page with list: [=>=>                                                    ] 8% | Count of all parsed: 390. Progress ratio: 14 %. Average price: 51 335 887 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 15 page...
#
# Average price per day: 51 497 946 rub
#
#  16 page: 28 offers
#  16 | 16 page with list: [=>                                                      ] 4% | Count of all parsed: 393. Progress ratio: 15 %. Average price: 51 392 741 rub
#  16 | 16 page with list: [=>=>                                                    ] 8% | Count of all parsed: 396. Progress ratio: 15 %. Average price: 51 240 333 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 16 page...
#
# Average price per day: 51 191 617 rub
#
#  17 page: 28 offers
#  17 | 17 page with list: [=>                                                      ] 4% | Count of all parsed: 399. Progress ratio: 15 %. Average price: 51 052 812 rub
#  17 | 17 page with list: [=>=>                                                    ] 8% | Count of all parsed: 402. Progress ratio: 15 %. Average price: 50 854 657 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 17 page...
#
# Average price per day: 50 799 186 rub
#
#  18 page: 28 offers
#  18 | 18 page with list: [=>                                                      ] 4% | Count of all parsed: 405. Progress ratio: 15 %. Average price: 51 478 427 rub
#  18 | 18 page with list: [=>=>                                                    ] 8% | Count of all parsed: 408. Progress ratio: 15 %. Average price: 51 605 658 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 18 page...
#
# Average price per day: 51 516 891 rub
#
#  19 page: 28 offers
#  19 | 19 page with list: [=>                                                      ] 4% | Count of all parsed: 411. Progress ratio: 15 %. Average price: 51 322 543 rub
#  19 | 19 page with list: [=>=>                                                    ] 8% | Count of all parsed: 414. Progress ratio: 15 %. Average price: 51 035 612 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 19 page...
#
# Average price per day: 50 943 237 rub
#
#  20 | 20 page with list: [=>                                                      ] 4% | Count of all parsed: 416. Progress ratio: 15 %. Average price: 50 880 788 rub
#  20 | 20 page with list: [=>=>                                                    ] 8% | Count of all parsed: 419. Progress ratio: 15 %. Average price: 50 697 069 rub
#  20 | 20 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 423. Progress ratio: 16 %. Average price: 50 458 930 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 20 page...
#
# Average price per day: 50 401 448 rub
#
#  21 page: 28 offers
#  21 | 21 page with list: [=>                                                      ] 4% | Count of all parsed: 426. Progress ratio: 16 %. Average price: 50 322 005 rub
#  21 | 21 page with list: [=>=>                                                    ] 8% | Count of all parsed: 429. Progress ratio: 16 %. Average price: 50 204 317 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 21 page...
#
# Average price per day: 50 166 438 rub
#
#  22 page: 28 offers
#  22 | 22 page with list: [=>                                                      ] 4% | Count of all parsed: 432. Progress ratio: 16 %. Average price: 50 169 408 rub
#  22 | 22 page with list: [=>=>                                                    ] 8% | Count of all parsed: 435. Progress ratio: 16 %. Average price: 50 174 599 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 22 page...
#
# Average price per day: 50 180 143 rub
#
#  23 page: 28 offers
#  23 | 23 page with list: [=>                                                      ] 4% | Count of all parsed: 438. Progress ratio: 16 %. Average price: 50 498 487 rub
#  23 | 23 page with list: [=>=>                                                    ] 8% | Count of all parsed: 441. Progress ratio: 16 %. Average price: 51 056 780 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 23 page...
#
# Average price per day: 51 257 970 rub
#
#  24 page: 28 offers
#  24 | 24 page with list: [=>                                                      ] 4% | Count of all parsed: 444. Progress ratio: 16 %. Average price: 51 071 123 rub
#  24 | 24 page with list: [=>=>                                                    ] 8% | Count of all parsed: 447. Progress ratio: 16 %. Average price: 50 794 086 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 24 page...
#
# Average price per day: 50 702 581 rub
#
#  25 page: 28 offers
#  25 | 25 page with list: [=>                                                      ] 4% | Count of all parsed: 450. Progress ratio: 17 %. Average price: 50 527 904 rub
#  25 | 25 page with list: [=>=>                                                    ] 8% | Count of all parsed: 453. Progress ratio: 17 %. Average price: 50 268 775 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 25 page...
#
# Average price per day: 50 183 381 rub
#
#  26 page: 28 offers
#  26 | 26 page with list: [=>                                                      ] 4% | Count of all parsed: 456. Progress ratio: 17 %. Average price: 50 018 730 rub
#  26 | 26 page with list: [=>=>                                                    ] 8% | Count of all parsed: 459. Progress ratio: 17 %. Average price: 49 773 867 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 26 page...
#
# Average price per day: 49 693 119 rub
#
#  27 page: 28 offers
#  27 | 27 page with list: [=>                                                      ] 4% | Count of all parsed: 462. Progress ratio: 17 %. Average price: 49 534 984 rub
#  27 | 27 page with list: [=>=>                                                    ] 8% | Count of all parsed: 465. Progress ratio: 17 %. Average price: 49 300 676 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 27 page...
#
# Average price per day: 49 223 287 rub
#
#  28 page: 28 offers
#  28 | 28 page with list: [=>                                                      ] 4% | Count of all parsed: 468. Progress ratio: 17 %. Average price: 49 072 760 rub
#  28 | 28 page with list: [=>=>                                                    ] 8% | Count of all parsed: 471. Progress ratio: 17 %. Average price: 48 849 463 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 28 page...
#
# Average price per day: 48 775 680 rub
#
#  29 page: 28 offers
#  29 | 29 page with list: [=>                                                      ] 4% | Count of all parsed: 474. Progress ratio: 17 %. Average price: 48 632 276 rub
#  29 | 29 page with list: [=>=>                                                    ] 8% | Count of all parsed: 477. Progress ratio: 18 %. Average price: 48 419 393 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 29 page...
#
# Average price per day: 48 348 850 rub
#
#  30 page: 28 offers
#  30 | 30 page with list: [=>                                                      ] 4% | Count of all parsed: 480. Progress ratio: 18 %. Average price: 48 211 172 rub
#  30 | 30 page with list: [=>=>                                                    ] 8% | Count of all parsed: 483. Progress ratio: 18 %. Average price: 48 006 571 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 30 page...
#
# Average price per day: 47 939 554 rub
#
#  31 page: 28 offers
#  31 | 31 page with list: [=>                                                      ] 4% | Count of all parsed: 486. Progress ratio: 18 %. Average price: 47 808 074 rub
#  31 | 31 page with list: [=>=>                                                    ] 8% | Count of all parsed: 489. Progress ratio: 18 %. Average price: 47 612 912 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 31 page...
#
# Average price per day: 47 548 394 rub
#
#  32 page: 28 offers
#  32 | 32 page with list: [=>                                                      ] 4% | Count of all parsed: 492. Progress ratio: 18 %. Average price: 47 423 734 rub
#  32 | 32 page with list: [=>=>                                                    ] 8% | Count of all parsed: 495. Progress ratio: 18 %. Average price: 47 238 305 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 32 page...
#
# Average price per day: 47 177 126 rub
#
#  33 page: 28 offers
#  33 | 33 page with list: [=>                                                      ] 4% | Count of all parsed: 498. Progress ratio: 18 %. Average price: 47 058 028 rub
#  33 | 33 page with list: [=>=>                                                    ] 8% | Count of all parsed: 501. Progress ratio: 18 %. Average price: 46 880 764 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 33 page...
#
# Average price per day: 46 822 223 rub
#
#  34 page: 28 offers
#  34 | 34 page with list: [=>                                                      ] 4% | Count of all parsed: 504. Progress ratio: 18 %. Average price: 46 710 540 rub
#  34 | 34 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 508. Progress ratio: 19 %. Average price: 46 490 277 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 34 page...
#
# Average price per day: 46 435 779 rub
#
#  35 page: 28 offers
#  35 | 35 page with list: [=>                                                      ] 4% | Count of all parsed: 511. Progress ratio: 19 %. Average price: 46 330 707 rub
#  35 | 35 page with list: [=>=>                                                    ] 8% | Count of all parsed: 514. Progress ratio: 19 %. Average price: 46 174 283 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 35 page...
#
# Average price per day: 46 122 488 rub
#
#  36 page: 28 offers
#  36 | 36 page with list: [=>                                                      ] 4% | Count of all parsed: 517. Progress ratio: 19 %. Average price: 46 024 027 rub
#  36 | 36 page with list: [=>=>                                                    ] 8% | Count of all parsed: 520. Progress ratio: 19 %. Average price: 45 877 870 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 36 page...
#
# Average price per day: 45 829 977 rub
#
#  37 page: 28 offers
#  37 | 37 page with list: [=>                                                      ] 4% | Count of all parsed: 523. Progress ratio: 19 %. Average price: 45 739 219 rub
#  37 | 37 page with list: [=>=>                                                    ] 8% | Count of all parsed: 526. Progress ratio: 19 %. Average price: 45 603 862 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 37 page...
#
# Average price per day: 45 559 220 rub
#
#  38 page: 28 offers
#  38 | 38 page with list: [=>                                                      ] 4% | Count of all parsed: 529. Progress ratio: 19 %. Average price: 45 474 308 rub
#  38 | 38 page with list: [=>=>                                                    ] 8% | Count of all parsed: 532. Progress ratio: 19 %. Average price: 45 348 104 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 38 page...
#
# Average price per day: 45 306 550 rub
#
#  39 page: 28 offers
#  39 | 39 page with list: [=>                                                      ] 4% | Count of all parsed: 535. Progress ratio: 20 %. Average price: 45 228 395 rub
#  39 | 39 page with list: [=>=>                                                    ] 8% | Count of all parsed: 538. Progress ratio: 20 %. Average price: 45 112 623 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 39 page...
#
# Average price per day: 45 074 566 rub
#
#  40 page: 28 offers
#  40 | 40 page with list: [=>                                                      ] 4% | Count of all parsed: 541. Progress ratio: 20 %. Average price: 45 004 863 rub
#  40 | 40 page with list: [=>=>                                                    ] 8% | Count of all parsed: 544. Progress ratio: 20 %. Average price: 44 901 932 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 40 page...
#
# Average price per day: 44 868 283 rub
#
#  41 page: 28 offers
#  41 | 41 page with list: [=>                                                      ] 4% | Count of all parsed: 547. Progress ratio: 20 %. Average price: 44 804 779 rub
#  41 | 41 page with list: [=>=>                                                    ] 8% | Count of all parsed: 550. Progress ratio: 20 %. Average price: 44 709 645 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 41 page...
#
# Average price per day: 44 678 111 rub
#
#  42 | 42 page with list: [=>                                                      ] 4% | Count of all parsed: 552. Progress ratio: 20 %. Average price: 44 649 595 rub
#  42 | 42 page with list: [=>=>                                                    ] 8% | Count of all parsed: 555. Progress ratio: 20 %. Average price: 44 563 707 rub
#  42 | 42 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 559. Progress ratio: 20 %. Average price: 44 451 379 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 42 page...
#
# Average price per day: 44 423 609 rub
#
#  43 page: 28 offers
#  43 | 43 page with list: [=>                                                      ] 4% | Count of all parsed: 562. Progress ratio: 21 %. Average price: 44 372 279 rub
#  43 | 43 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 566. Progress ratio: 21 %. Average price: 44 271 055 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 43 page...
#
# Average price per day: 44 246 710 rub
#
#  44 | 44 page with list: [=>                                                      ] 4% | Count of all parsed: 568. Progress ratio: 21 %. Average price: 44 226 756 rub
#  44 | 44 page with list: [=>=>                                                    ] 8% | Count of all parsed: 571. Progress ratio: 21 %. Average price: 44 166 431 rub
#  44 | 44 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 575. Progress ratio: 21 %. Average price: 44 087 663 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 44 page...
#
# Average price per day: 44 068 544 rub
#
#  45 page: 28 offers
#  45 | 45 page with list: [=>                                                      ] 4% | Count of all parsed: 578. Progress ratio: 21 %. Average price: 44 036 819 rub
#  45 | 45 page with list: [=>=>                                                    ] 8% | Count of all parsed: 581. Progress ratio: 21 %. Average price: 43 989 641 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 45 page...
#
# Average price per day: 43 974 648 rub
#
#  46 page: 28 offers
#  46 | 46 page with list: [=>                                                      ] 4% | Count of all parsed: 584. Progress ratio: 21 %. Average price: 43 956 091 rub
#  46 | 46 page with list: [=>=>                                                    ] 8% | Count of all parsed: 587. Progress ratio: 21 %. Average price: 43 929 627 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 46 page...
#
# Average price per day: 43 921 243 rub
#
#  47 page: 28 offers
#  47 | 47 page with list: [=>                                                      ] 4% | Count of all parsed: 590. Progress ratio: 22 %. Average price: 43 927 612 rub
#  47 | 47 page with list: [=>=>                                                    ] 8% | Count of all parsed: 593. Progress ratio: 22 %. Average price: 43 937 759 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 47 page...
#
# Average price per day: 43 941 231 rub
#
#  48 page: 28 offers
#  48 | 48 page with list: [=>                                                      ] 4% | Count of all parsed: 596. Progress ratio: 22 %. Average price: 43 978 307 rub
#  48 | 48 page with list: [=>=>                                                    ] 8% | Count of all parsed: 599. Progress ratio: 22 %. Average price: 44 033 491 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 48 page...
#
# Average price per day: 44 051 602 rub
#
#  49 page: 28 offers
#  49 | 49 page with list: [=>                                                      ] 4% | Count of all parsed: 602. Progress ratio: 22 %. Average price: 44 152 855 rub
#  49 | 49 page with list: [=>=>                                                    ] 8% | Count of all parsed: 605. Progress ratio: 22 %. Average price: 44 314 311 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 49 page...
#
# Average price per day: 44 373 198 rub
#
#  50 page: 28 offers
#  50 | 50 page with list: [=>                                                      ] 4% | Count of all parsed: 608. Progress ratio: 22 %. Average price: 44 567 530 rub
#  50 | 50 page with list: [=>=>                                                    ] 8% | Count of all parsed: 611. Progress ratio: 22 %. Average price: 44 856 773 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 50 page...
#
# Average price per day: 44 955 046 rub
#
#  51 | 51 page with list: [=>                                                      ] 4% | Count of all parsed: 613. Progress ratio: 22 %. Average price: 45 201 220 rub
#  51 | 51 page with list: [=>=>                                                    ] 8% | Count of all parsed: 616. Progress ratio: 22 %. Average price: 45 969 481 rub
#  51 | 51 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 620. Progress ratio: 23 %. Average price: 47 015 768 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 51 page...
#
# Average price per day: 47 301 122 rub
#
#  52 page: 28 offers
#  52 | 52 page with list: [=>                                                      ] 4% | Count of all parsed: 623. Progress ratio: 23 %. Average price: 47 173 586 rub
#  52 | 52 page with list: [=>=>                                                    ] 8% | Count of all parsed: 626. Progress ratio: 23 %. Average price: 46 983 790 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 52 page...
#
# Average price per day: 46 920 855 rub
#
#  53 page: 28 offers
#  53 | 53 page with list: [=>                                                      ] 4% | Count of all parsed: 629. Progress ratio: 23 %. Average price: 46 796 751 rub
#  53 | 53 page with list: [=>=>                                                    ] 8% | Count of all parsed: 632. Progress ratio: 23 %. Average price: 46 611 999 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 53 page...
#
# Average price per day: 46 550 889 rub
#
#  54 page: 25 offers
#  54 | 54 page with list: [=>                                                ] 4% | Count of all parsed: 635. Progress ratio: 26 %. Average price: 46 430 246 rub
#  54 | 54 page with list: [=>=>                                              ] 8% | Count of all parsed: 638. Progress ratio: 26 %. Average price: 46 250 581 rub
#
# Exception: 'charmap' codec can't encode character '\xe9' in position 250: character maps to <undefined>
# The collection of information from the pages with ending parse on 54 page...
#
# Average price per day: 46 190 955 rub
#
#  55 | 55 page: cian is redirecting from page 55 to page 1... there is maximum value of page, you should try to decrease number of page... ending...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 639. Average price: 46 190 955 rub

# %%
data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location = "Москва",
    rooms=3,
    is_saving_csv=True,
    is_latin=False,
    is_express_mode=False,
)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_moskva_07_Jan_2024_06_35_53_932296.csv
#
#
# Exception: HTTPSConnectionPool(host='www.cian.ru', port=443): Max retries exceeded with url: /cat.php?engine_version=2&p=1&region=1&offer_type=flat&deal_type=sale&room3=1&with_neighbors=0 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002706C478550>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# The collection of information from the pages with ending parse on 1 page...
#
# Average price per day: 0 rub
#
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 98 499 344 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 2 %. Average price: 89 637 047 rub
#  4 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 3 %. Average price: 88 382 223 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 112. Progress ratio: 4 %. Average price: 80 316 015 rub
#  6 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 140. Progress ratio: 5 %. Average price: 76 632 450 rub
#  7 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 168. Progress ratio: 6 %. Average price: 73 060 602 rub
#  8 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 196. Progress ratio: 7 %. Average price: 67 330 508 rub
#  9 | 9 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 224. Progress ratio: 8 %. Average price: 67 389 808 rub
#  10 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 252. Progress ratio: 9 %. Average price: 68 945 438 rub
#  11 | 11 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 255. Progress ratio: 10 %. Average price: 68 765 506 rub
#  11 | 11 page with list: [=>=>=>=>                                                ] 15% | Count of all parsed: 260. Progress ratio: 10 %. Average price: 68 577 452 rub
#  11 | 11 page with list: [=>=>=>=>=>                                              ] 18% | Count of all parsed: 266. Progress ratio: 10 %. Average price: 68 172 463 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 11 page...
#
# Average price per day: 68 310 394 rub
#
#  12 page: 28 offers
#  12 | 12 page with list: [=>                                                      ] 4% | Count of all parsed: 269. Progress ratio: 10 %. Average price: 68 105 678 rub
#  12 | 12 page with list: [=>=>                                                    ] 8% | Count of all parsed: 272. Progress ratio: 10 %. Average price: 69 636 777 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 12 page...
#
# Average price per day: 70 719 316 rub
#
#  13 page: 28 offers
#  13 | 13 page with list: [=>                                                      ] 4% | Count of all parsed: 275. Progress ratio: 10 %. Average price: 72 186 696 rub
#  13 | 13 page with list: [=>=>                                                    ] 8% | Count of all parsed: 278. Progress ratio: 10 %. Average price: 72 477 789 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 13 page...
#
# Average price per day: 72 372 024 rub
#
#  14 page: 28 offers
#  14 | 14 page with list: [=>                                                      ] 4% | Count of all parsed: 281. Progress ratio: 11 %. Average price: 76 490 657 rub
#  14 | 14 page with list: [=>=>                                                    ] 8% | Count of all parsed: 284. Progress ratio: 11 %. Average price: 78 524 347 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 14 page...
#
# Average price per day: 79 887 069 rub
#
#  15 page: 28 offers
#  15 | 15 page with list: [=>                                                      ] 4% | Count of all parsed: 287. Progress ratio: 11 %. Average price: 79 820 416 rub
#  15 | 15 page with list: [=>=>                                                    ] 8% | Count of all parsed: 290. Progress ratio: 11 %. Average price: 79 605 454 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 15 page...
#
# Average price per day: 79 494 986 rub
#
#  16 page: 28 offers
#  16 | 16 page with list: [=>                                                      ] 4% | Count of all parsed: 293. Progress ratio: 11 %. Average price: 79 355 089 rub
#  16 | 16 page with list: [=>=>                                                    ] 8% | Count of all parsed: 296. Progress ratio: 11 %. Average price: 79 169 057 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 16 page...
#
# Average price per day: 79 111 249 rub
#
#  17 page: 28 offers
#  17 | 17 page with list: [=>                                                      ] 4% | Count of all parsed: 299. Progress ratio: 11 %. Average price: 79 919 870 rub
#  17 | 17 page with list: [=>=>                                                    ] 8% | Count of all parsed: 302. Progress ratio: 11 %. Average price: 81 151 626 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 17 page...
#
# Average price per day: 81 571 857 rub
#
#  18 page: 28 offers
#  18 | 18 page with list: [=>                                                      ] 4% | Count of all parsed: 305. Progress ratio: 11 %. Average price: 84 643 311 rub
#  18 | 18 page with list: [=>=>                                                    ] 8% | Count of all parsed: 308. Progress ratio: 11 %. Average price: 85 734 281 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 18 page...
#
# Average price per day: 85 553 911 rub
#
#  19 page: 28 offers
#  19 | 19 page with list: [=>                                                      ] 4% | Count of all parsed: 311. Progress ratio: 12 %. Average price: 85 839 738 rub
#  19 | 19 page with list: [=>=>                                                    ] 8% | Count of all parsed: 314. Progress ratio: 12 %. Average price: 86 274 390 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 19 page...
#
# Average price per day: 86 646 954 rub
#
#  20 page: 28 offers
#  20 | 20 page with list: [=>                                                      ] 4% | Count of all parsed: 317. Progress ratio: 12 %. Average price: 86 920 475 rub
#  20 | 20 page with list: [=>=>                                                    ] 8% | Count of all parsed: 320. Progress ratio: 12 %. Average price: 87 586 845 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 20 page...
#
# Average price per day: 89 027 385 rub
#
#  21 page: 28 offers
#  21 | 21 page with list: [=>                                                      ] 4% | Count of all parsed: 323. Progress ratio: 12 %. Average price: 88 748 578 rub
#  21 | 21 page with list: [=>=>                                                    ] 8% | Count of all parsed: 326. Progress ratio: 12 %. Average price: 88 361 321 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 21 page...
#
# Average price per day: 88 238 503 rub
#
#  22 page: 28 offers
#  22 | 22 page with list: [=>                                                      ] 4% | Count of all parsed: 329. Progress ratio: 12 %. Average price: 87 963 497 rub
#  22 | 22 page with list: [=>=>                                                    ] 8% | Count of all parsed: 332. Progress ratio: 12 %. Average price: 87 607 140 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 22 page...
#
# Average price per day: 87 503 515 rub
#
#  23 page: 28 offers
#  23 | 23 page with list: [=>                                                      ] 4% | Count of all parsed: 335. Progress ratio: 12 %. Average price: 87 727 375 rub
#  23 | 23 page with list: [=>=>                                                    ] 8% | Count of all parsed: 338. Progress ratio: 13 %. Average price: 88 100 910 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 23 page...
#
# Average price per day: 88 457 544 rub
#
#  24 | 24 page with list: [=>                                                      ] 4% | Count of all parsed: 340. Progress ratio: 13 %. Average price: 88 244 569 rub
#  24 | 24 page with list: [=>=>                                                    ] 8% | Count of all parsed: 343. Progress ratio: 13 %. Average price: 87 626 999 rub
#  24 | 24 page with list: [=>=>=>=>                                                ] 15% | Count of all parsed: 348. Progress ratio: 13 %. Average price: 86 629 128 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 24 page...
#
# Average price per day: 86 439 360 rub
#
#  25 page: 28 offers
#  25 | 25 page with list: [=>=>                                                    ] 8% | Count of all parsed: 352. Progress ratio: 13 %. Average price: 85 991 172 rub
#  25 | 25 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 356. Progress ratio: 13 %. Average price: 85 406 931 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 25 page...
#
# Average price per day: 85 262 934 rub
#
#  26 page: 28 offers
#  26 | 26 page with list: [=>                                                      ] 4% | Count of all parsed: 359. Progress ratio: 13 %. Average price: 85 015 174 rub
#  26 | 26 page with list: [=>=>                                                    ] 8% | Count of all parsed: 362. Progress ratio: 13 %. Average price: 84 650 694 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 26 page...
#
# Average price per day: 84 531 822 rub
#
#  27 page: 28 offers
#  27 | 27 page with list: [=>                                                      ] 4% | Count of all parsed: 365. Progress ratio: 14 %. Average price: 84 414 353 rub
#  27 | 27 page with list: [=>=>                                                    ] 8% | Count of all parsed: 368. Progress ratio: 14 %. Average price: 84 243 567 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 27 page...
#
# Average price per day: 84 187 379 rub
#
#  28 page: 28 offers
#  28 | 28 page with list: [=>=>                                                    ] 8% | Count of all parsed: 372. Progress ratio: 14 %. Average price: 84 363 544 rub
#  28 | 28 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 376. Progress ratio: 14 %. Average price: 84 613 728 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 28 page...
#
# Average price per day: 84 678 017 rub
#
#  29 page: 28 offers
#  29 | 29 page with list: [=>                                                      ] 4% | Count of all parsed: 379. Progress ratio: 14 %. Average price: 85 192 856 rub
#  29 | 29 page with list: [=>=>                                                    ] 8% | Count of all parsed: 382. Progress ratio: 14 %. Average price: 85 962 552 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 29 page...
#
# Average price per day: 86 214 765 rub
#
#  30 page: 28 offers
#  30 | 30 page with list: [=>                                                      ] 4% | Count of all parsed: 385. Progress ratio: 14 %. Average price: 88 365 329 rub
#  30 | 30 page with list: [=>=>                                                    ] 8% | Count of all parsed: 388. Progress ratio: 14 %. Average price: 91 790 851 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 30 page...
#
# Average price per day: 93 069 255 rub
#
#  31 page: 28 offers
#  31 | 31 page with list: [=>=>                                                    ] 8% | Count of all parsed: 392. Progress ratio: 14 %. Average price: 92 466 281 rub
#  31 | 31 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 396. Progress ratio: 15 %. Average price: 91 676 683 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 31 page...
#
# Average price per day: 91 482 283 rub
#
#  32 page: 28 offers
#  32 | 32 page with list: [=>                                                      ] 4% | Count of all parsed: 399. Progress ratio: 15 %. Average price: 91 103 970 rub
#  32 | 32 page with list: [=>=>                                                    ] 8% | Count of all parsed: 402. Progress ratio: 15 %. Average price: 90 543 416 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 32 page...
#
# Average price per day: 90 358 196 rub
#
#  33 page: 28 offers
#  33 | 33 page with list: [=>                                                      ] 4% | Count of all parsed: 405. Progress ratio: 15 %. Average price: 89 998 403 rub
#  33 | 33 page with list: [=>=>                                                    ] 8% | Count of all parsed: 408. Progress ratio: 15 %. Average price: 89 464 836 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 33 page...
#
# Average price per day: 89 289 388 rub
#
#  34 page: 28 offers
#  34 | 34 page with list: [=>                                                      ] 4% | Count of all parsed: 411. Progress ratio: 15 %. Average price: 88 945 248 rub
#  34 | 34 page with list: [=>=>                                                    ] 8% | Count of all parsed: 414. Progress ratio: 15 %. Average price: 88 435 328 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 34 page...
#
# Average price per day: 88 266 706 rub
#
#  35 page: 28 offers
#  35 | 35 page with list: [=>                                                      ] 4% | Count of all parsed: 417. Progress ratio: 15 %. Average price: 87 940 086 rub
#  35 | 35 page with list: [=>=>                                                    ] 8% | Count of all parsed: 420. Progress ratio: 15 %. Average price: 87 456 053 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 35 page...
#
# Average price per day: 87 296 148 rub
#
#  36 page: 28 offers
#  36 | 36 page with list: [=>                                                      ] 4% | Count of all parsed: 423. Progress ratio: 16 %. Average price: 86 984 730 rub
#  36 | 36 page with list: [=>=>                                                    ] 8% | Count of all parsed: 426. Progress ratio: 16 %. Average price: 86 522 595 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 36 page...
#
# Average price per day: 86 370 088 rub
#
#  37 page: 28 offers
#  37 | 37 page with list: [=>                                                      ] 4% | Count of all parsed: 429. Progress ratio: 16 %. Average price: 86 072 688 rub
#  37 | 37 page with list: [=>=>                                                    ] 8% | Count of all parsed: 432. Progress ratio: 16 %. Average price: 85 632 317 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 37 page...
#
# Average price per day: 85 487 074 rub
#
#  38 page: 28 offers
#  38 | 38 page with list: [=>                                                      ] 4% | Count of all parsed: 435. Progress ratio: 16 %. Average price: 85 207 280 rub
#  38 | 38 page with list: [=>=>                                                    ] 8% | Count of all parsed: 438. Progress ratio: 16 %. Average price: 84 792 353 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 38 page...
#
# Average price per day: 84 655 013 rub
#
#  39 page: 28 offers
#  39 | 39 page with list: [=>                                                      ] 4% | Count of all parsed: 441. Progress ratio: 16 %. Average price: 84 388 916 rub
#  39 | 39 page with list: [=>=>                                                    ] 8% | Count of all parsed: 444. Progress ratio: 16 %. Average price: 83 995 175 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 39 page...
#
# Average price per day: 83 865 247 rub
#
#  40 page: 28 offers
#  40 | 40 page with list: [=>                                                      ] 4% | Count of all parsed: 447. Progress ratio: 16 %. Average price: 83 613 053 rub
#  40 | 40 page with list: [=>=>                                                    ] 8% | Count of all parsed: 450. Progress ratio: 17 %. Average price: 83 239 550 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 40 page...
#
# Average price per day: 83 116 071 rub
#
#  41 page: 28 offers
#  41 | 41 page with list: [=>                                                      ] 4% | Count of all parsed: 453. Progress ratio: 17 %. Average price: 82 878 045 rub
#  41 | 41 page with list: [=>=>                                                    ] 8% | Count of all parsed: 456. Progress ratio: 17 %. Average price: 82 524 029 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 41 page...
#
# Average price per day: 82 407 325 rub
#
#  42 | 42 page with list: [=>                                                      ] 4% | Count of all parsed: 458. Progress ratio: 17 %. Average price: 82 295 434 rub
#  42 | 42 page with list: [=>=>                                                    ] 8% | Count of all parsed: 461. Progress ratio: 17 %. Average price: 81 963 276 rub
#  42 | 42 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 465. Progress ratio: 17 %. Average price: 81 528 401 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 42 page...
#
# Average price per day: 81 421 449 rub
#
#  43 page: 28 offers
#  43 | 43 page with list: [=>                                                      ] 4% | Count of all parsed: 468. Progress ratio: 17 %. Average price: 81 216 186 rub
#  43 | 43 page with list: [=>=>                                                    ] 8% | Count of all parsed: 471. Progress ratio: 17 %. Average price: 80 912 028 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 43 page...
#
# Average price per day: 80 811 579 rub
#
#  44 page: 28 offers
#  44 | 44 page with list: [=>                                                      ] 4% | Count of all parsed: 474. Progress ratio: 17 %. Average price: 80 622 078 rub
#  44 | 44 page with list: [=>=>                                                    ] 8% | Count of all parsed: 477. Progress ratio: 18 %. Average price: 80 340 807 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 44 page...
#
# Average price per day: 80 248 034 rub
#
#  45 page: 28 offers
#  45 | 45 page with list: [=>                                                      ] 4% | Count of all parsed: 480. Progress ratio: 18 %. Average price: 80 074 084 rub
#  45 | 45 page with list: [=>=>                                                    ] 8% | Count of all parsed: 483. Progress ratio: 18 %. Average price: 79 816 273 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 45 page...
#
# Average price per day: 79 730 909 rub
#
#  46 | 46 page with list: [=>                                                      ] 4% | Count of all parsed: 485. Progress ratio: 18 %. Average price: 79 649 865 rub
#  46 | 46 page with list: [=>=>                                                    ] 8% | Count of all parsed: 488. Progress ratio: 18 %. Average price: 79 408 370 rub
#  46 | 46 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 492. Progress ratio: 18 %. Average price: 79 093 436 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 46 page...
#
# Average price per day: 79 015 762 rub
#
#  47 page: 28 offers
#  47 | 47 page with list: [=>                                                      ] 4% | Count of all parsed: 495. Progress ratio: 18 %. Average price: 78 866 204 rub
#  47 | 47 page with list: [=>=>                                                    ] 8% | Count of all parsed: 498. Progress ratio: 18 %. Average price: 78 643 716 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 47 page...
#
# Average price per day: 78 570 282 rub
#
#  48 page: 28 offers
#  48 | 48 page with list: [=>                                                      ] 4% | Count of all parsed: 501. Progress ratio: 18 %. Average price: 78 436 269 rub
#  48 | 48 page with list: [=>=>                                                    ] 8% | Count of all parsed: 504. Progress ratio: 18 %. Average price: 78 237 244 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 48 page...
#
# Average price per day: 78 172 417 rub
#
#  49 page: 28 offers
#  49 | 49 page with list: [=>                                                      ] 4% | Count of all parsed: 507. Progress ratio: 19 %. Average price: 78 065 228 rub
#  49 | 49 page with list: [=>=>                                                    ] 8% | Count of all parsed: 510. Progress ratio: 19 %. Average price: 77 906 669 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 49 page...
#
# Average price per day: 77 854 406 rub
#
#  50 page: 28 offers
#  50 | 50 page with list: [=>                                                      ] 4% | Count of all parsed: 513. Progress ratio: 19 %. Average price: 77 784 798 rub
#  50 | 50 page with list: [=>=>                                                    ] 8% | Count of all parsed: 516. Progress ratio: 19 %. Average price: 77 680 623 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 50 page...
#
# Average price per day: 77 646 231 rub
#
#  51 page: 28 offers
#  51 | 51 page with list: [=>                                                      ] 4% | Count of all parsed: 519. Progress ratio: 19 %. Average price: 77 620 619 rub
#  51 | 51 page with list: [=>=>                                                    ] 8% | Count of all parsed: 522. Progress ratio: 19 %. Average price: 77 585 654 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 51 page...
#
# Average price per day: 77 574 498 rub
#
#  52 page: 28 offers
#  52 | 52 page with list: [=>                                                      ] 4% | Count of all parsed: 525. Progress ratio: 19 %. Average price: 77 595 166 rub
#  52 | 52 page with list: [=>=>                                                    ] 8% | Count of all parsed: 528. Progress ratio: 19 %. Average price: 77 629 663 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 52 page...
#
# Average price per day: 77 641 706 rub
#
#  53 page: 28 offers
#  53 | 53 page with list: [=>                                                      ] 4% | Count of all parsed: 531. Progress ratio: 19 %. Average price: 77 720 860 rub
#  53 | 53 page with list: [=>=>                                                    ] 8% | Count of all parsed: 534. Progress ratio: 20 %. Average price: 77 841 928 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 53 page...
#
# Average price per day: 77 881 476 rub
#
#  54 page: 25 offers
#  54 | 54 page with list: [=>                                                ] 4% | Count of all parsed: 537. Progress ratio: 22 %. Average price: 78 034 618 rub
#  54 | 54 page with list: [=>=>                                              ] 8% | Count of all parsed: 540. Progress ratio: 22 %. Average price: 78 265 907 rub
#
# Exception: 'charmap' codec can't encode character '\xb2' in position 241: character maps to <undefined>
# The collection of information from the pages with ending parse on 54 page...
#
# Average price per day: 78 343 049 rub
#
#  55 | 55 page: cian is redirecting from page 55 to page 1... there is maximum value of page, you should try to decrease number of page... ending...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 541. Average price: 78 343 049 rub

# %%
data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location = "Москва",
    rooms=4,
    is_saving_csv=True,
    is_latin=False,
    is_express_mode=False,
)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_moskva_07_Jan_2024_07_11_05_189339.csv
#
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 195 559 300 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 2 %. Average price: 153 752 101 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 3 %. Average price: 154 633 708 rub
#  4 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 112. Progress ratio: 4 %. Average price: 136 550 301 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>                                    ] 36% | Count of all parsed: 122. Progress ratio: 5 %. Average price: 130 702 986 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>                                  ] 40% | Count of all parsed: 134. Progress ratio: 5 %. Average price: 124 600 847 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>                                ] 43% | Count of all parsed: 147. Progress ratio: 6 %. Average price: 120 061 773 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 5 page...
#
# Average price per day: 119 729 161 rub
#
#  6 page: 28 offers
#  6 | 6 page with list: [=>                                                      ] 4% | Count of all parsed: 150. Progress ratio: 6 %. Average price: 118 436 959 rub
#  6 | 6 page with list: [=>=>                                                    ] 8% | Count of all parsed: 153. Progress ratio: 6 %. Average price: 117 963 123 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 6 page...
#
# Average price per day: 117 284 359 rub
#
#  7 page: 28 offers
#  7 | 7 page with list: [=>                                                      ] 4% | Count of all parsed: 156. Progress ratio: 6 %. Average price: 115 934 175 rub
#  7 | 7 page with list: [=>=>                                                    ] 8% | Count of all parsed: 159. Progress ratio: 6 %. Average price: 116 589 316 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 7 page...
#
# Average price per day: 116 063 658 rub
#
#  8 page: 28 offers
#  8 | 8 page with list: [=>                                                      ] 4% | Count of all parsed: 162. Progress ratio: 6 %. Average price: 116 637 201 rub
#  8 | 8 page with list: [=>=>                                                    ] 8% | Count of all parsed: 165. Progress ratio: 6 %. Average price: 118 719 680 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 8 page...
#
# Average price per day: 118 321 715 rub
#
#  9 page: 28 offers
#  9 | 9 page with list: [=>                                                      ] 4% | Count of all parsed: 168. Progress ratio: 6 %. Average price: 118 064 895 rub
#  9 | 9 page with list: [=>=>                                                    ] 8% | Count of all parsed: 171. Progress ratio: 7 %. Average price: 117 845 913 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 9 page...
#
# Average price per day: 120 105 297 rub
#
#  10 page: 28 offers
#  10 | 10 page with list: [=>                                                      ] 4% | Count of all parsed: 174. Progress ratio: 7 %. Average price: 120 057 269 rub
#  10 | 10 page with list: [=>=>                                                    ] 8% | Count of all parsed: 177. Progress ratio: 7 %. Average price: 120 999 048 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 10 page...
#
# Average price per day: 121 337 930 rub
#
#  11 page: 28 offers
#  11 | 11 page with list: [=>                                                      ] 4% | Count of all parsed: 180. Progress ratio: 7 %. Average price: 122 134 843 rub
#  11 | 11 page with list: [=>=>                                                    ] 8% | Count of all parsed: 183. Progress ratio: 7 %. Average price: 125 012 742 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 11 page...
#
# Average price per day: 125 364 909 rub
#
#  12 page: 28 offers
#  12 | 12 page with list: [=>                                                      ] 4% | Count of all parsed: 186. Progress ratio: 7 %. Average price: 131 803 651 rub
#  12 | 12 page with list: [=>=>                                                    ] 8% | Count of all parsed: 189. Progress ratio: 7 %. Average price: 134 585 434 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 12 page...
#
# Average price per day: 134 912 204 rub
#
#  13 page: 28 offers
#  13 | 13 page with list: [=>                                                      ] 4% | Count of all parsed: 192. Progress ratio: 7 %. Average price: 134 035 615 rub
#  13 | 13 page with list: [=>=>                                                    ] 8% | Count of all parsed: 195. Progress ratio: 7 %. Average price: 133 515 886 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 13 page...
#
# Average price per day: 133 468 873 rub
#
#  14 page: 28 offers
#  14 | 14 page with list: [=>                                                      ] 4% | Count of all parsed: 198. Progress ratio: 8 %. Average price: 132 536 052 rub
#  14 | 14 page with list: [=>=>                                                    ] 8% | Count of all parsed: 201. Progress ratio: 8 %. Average price: 132 384 368 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 14 page...
#
# Average price per day: 131 970 188 rub
#
#  15 page: 28 offers
#  15 | 15 page with list: [=>                                                      ] 4% | Count of all parsed: 204. Progress ratio: 8 %. Average price: 131 748 810 rub
#  15 | 15 page with list: [=>=>                                                    ] 8% | Count of all parsed: 207. Progress ratio: 8 %. Average price: 131 720 517 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 15 page...
#
# Average price per day: 131 442 714 rub
#
#  16 page: 28 offers
#  16 | 16 page with list: [=>                                                      ] 4% | Count of all parsed: 210. Progress ratio: 8 %. Average price: 130 623 545 rub
#  16 | 16 page with list: [=>=>                                                    ] 8% | Count of all parsed: 213. Progress ratio: 8 %. Average price: 129 441 664 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 16 page...
#
# Average price per day: 129 063 386 rub
#
#  17 page: 28 offers
#  17 | 17 page with list: [=>                                                      ] 4% | Count of all parsed: 216. Progress ratio: 8 %. Average price: 128 933 169 rub
#  17 | 17 page with list: [=>=>                                                    ] 8% | Count of all parsed: 219. Progress ratio: 8 %. Average price: 128 778 825 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 17 page...
#
# Average price per day: 128 747 319 rub
#
#  18 page: 28 offers
#  18 | 18 page with list: [=>=>                                                    ] 8% | Count of all parsed: 223. Progress ratio: 8 %. Average price: 131 203 320 rub
#  18 | 18 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 227. Progress ratio: 9 %. Average price: 134 470 024 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 18 page...
#
# Average price per day: 135 344 306 rub
#
#  19 page: 28 offers
#  19 | 19 page with list: [=>                                                      ] 4% | Count of all parsed: 230. Progress ratio: 9 %. Average price: 134 299 681 rub
#  19 | 19 page with list: [=>=>                                                    ] 8% | Count of all parsed: 233. Progress ratio: 9 %. Average price: 132 770 919 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 19 page...
#
# Average price per day: 132 271 891 rub
#
#  20 page: 28 offers
#  20 | 20 page with list: [=>                                                      ] 4% | Count of all parsed: 236. Progress ratio: 9 %. Average price: 131 357 421 rub
#  20 | 20 page with list: [=>=>                                                    ] 8% | Count of all parsed: 239. Progress ratio: 9 %. Average price: 130 013 046 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 20 page...
#
# Average price per day: 129 572 808 rub
#
#  21 page: 28 offers
#  21 | 21 page with list: [=>                                                      ] 4% | Count of all parsed: 242. Progress ratio: 9 %. Average price: 128 761 846 rub
#  21 | 21 page with list: [=>=>                                                    ] 8% | Count of all parsed: 245. Progress ratio: 9 %. Average price: 127 576 008 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 21 page...
#
# Average price per day: 127 187 488 rub
#
#  22 page: 28 offers
#  22 | 22 page with list: [=>                                                      ] 4% | Count of all parsed: 248. Progress ratio: 9 %. Average price: 126 460 170 rub
#  22 | 22 page with list: [=>=>                                                    ] 8% | Count of all parsed: 251. Progress ratio: 9 %. Average price: 125 393 788 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 22 page...
#
# Average price per day: 125 046 012 rub
#
#  23 page: 28 offers
#  23 | 23 page with list: [=>                                                      ] 4% | Count of all parsed: 254. Progress ratio: 10 %. Average price: 124 407 067 rub
#  23 | 23 page with list: [=>=>                                                    ] 8% | Count of all parsed: 257. Progress ratio: 10 %. Average price: 123 471 449 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 23 page...
#
# Average price per day: 123 165 152 rub
#
#  24 page: 28 offers
#  24 | 24 page with list: [=>                                                      ] 4% | Count of all parsed: 260. Progress ratio: 10 %. Average price: 122 602 343 rub
#  24 | 24 page with list: [=>=>                                                    ] 8% | Count of all parsed: 263. Progress ratio: 10 %. Average price: 121 774 179 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 24 page...
#
# Average price per day: 121 503 747 rub
#
#  25 page: 28 offers
#  25 | 25 page with list: [=>                                                      ] 4% | Count of all parsed: 266. Progress ratio: 10 %. Average price: 121 018 531 rub
#  25 | 25 page with list: [=>=>                                                    ] 8% | Count of all parsed: 269. Progress ratio: 10 %. Average price: 120 304 592 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 25 page...
#
# Average price per day: 120 070 131 rub
#
#  26 page: 28 offers
#  26 | 26 page with list: [=>                                                      ] 4% | Count of all parsed: 272. Progress ratio: 10 %. Average price: 119 658 634 rub
#  26 | 26 page with list: [=>=>                                                    ] 8% | Count of all parsed: 275. Progress ratio: 10 %. Average price: 119 053 857 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 26 page...
#
# Average price per day: 118 856 198 rub
#
#  27 page: 28 offers
#  27 | 27 page with list: [=>                                                      ] 4% | Count of all parsed: 278. Progress ratio: 10 %. Average price: 118 503 151 rub
#  27 | 27 page with list: [=>=>                                                    ] 8% | Count of all parsed: 281. Progress ratio: 11 %. Average price: 117 984 551 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 27 page...
#
# Average price per day: 117 814 393 rub
#
#  28 page: 28 offers
#  28 | 28 page with list: [=>                                                      ] 4% | Count of all parsed: 284. Progress ratio: 11 %. Average price: 117 536 120 rub
#  28 | 28 page with list: [=>=>                                                    ] 8% | Count of all parsed: 287. Progress ratio: 11 %. Average price: 117 123 894 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 28 page...
#
# Average price per day: 116 988 394 rub
#
#  29 page: 28 offers
#  29 | 29 page with list: [=>                                                      ] 4% | Count of all parsed: 290. Progress ratio: 11 %. Average price: 116 836 750 rub
#  29 | 29 page with list: [=>=>                                                    ] 8% | Count of all parsed: 293. Progress ratio: 11 %. Average price: 116 613 159 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 29 page...
#
# Average price per day: 116 539 645 rub
#
#  30 page: 28 offers
#  30 | 30 page with list: [=>                                                      ] 4% | Count of all parsed: 296. Progress ratio: 11 %. Average price: 116 596 809 rub
#  30 | 30 page with list: [=>=>                                                    ] 8% | Count of all parsed: 299. Progress ratio: 11 %. Average price: 116 681 122 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 30 page...
#
# Average price per day: 116 715 519 rub
#
#  31 page: 28 offers
#  31 | 31 page with list: [=>                                                      ] 4% | Count of all parsed: 302. Progress ratio: 11 %. Average price: 116 969 058 rub
#  31 | 31 page with list: [=>=>                                                    ] 8% | Count of all parsed: 305. Progress ratio: 11 %. Average price: 117 340 486 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 31 page...
#
# Average price per day: 117 463 557 rub
#
#  32 page: 28 offers
#  32 | 32 page with list: [=>                                                      ] 4% | Count of all parsed: 308. Progress ratio: 11 %. Average price: 117 869 638 rub
#  32 | 32 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 312. Progress ratio: 12 %. Average price: 118 746 502 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 32 page...
#
# Average price per day: 118 990 123 rub
#
#  33 page: 28 offers
#  33 | 33 page with list: [=>                                                      ] 4% | Count of all parsed: 315. Progress ratio: 12 %. Average price: 119 745 259 rub
#  33 | 33 page with list: [=>=>                                                    ] 8% | Count of all parsed: 318. Progress ratio: 12 %. Average price: 120 892 077 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 33 page...
#
# Average price per day: 121 274 860 rub
#
#  34 page: 28 offers
#  34 | 34 page with list: [=>                                                      ] 4% | Count of all parsed: 321. Progress ratio: 12 %. Average price: 122 642 715 rub
#  34 | 34 page with list: [=>=>                                                    ] 8% | Count of all parsed: 324. Progress ratio: 12 %. Average price: 124 694 837 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 34 page...
#
# Average price per day: 125 388 083 rub
#
#  35 page: 28 offers
#  35 | 35 page with list: [=>=>                                                    ] 8% | Count of all parsed: 328. Progress ratio: 12 %. Average price: 131 866 363 rub
#  35 | 35 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 332. Progress ratio: 12 %. Average price: 135 587 732 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 35 page...
#
# Average price per day: 135 216 808 rub
#
#  36 page: 28 offers
#  36 | 36 page with list: [=>                                                      ] 4% | Count of all parsed: 335. Progress ratio: 12 %. Average price: 134 493 425 rub
#  36 | 36 page with list: [=>=>                                                    ] 8% | Count of all parsed: 338. Progress ratio: 13 %. Average price: 133 424 183 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 36 page...
#
# Average price per day: 133 071 899 rub
#
#  37 page: 28 offers
#  37 | 37 page with list: [=>                                                      ] 4% | Count of all parsed: 341. Progress ratio: 13 %. Average price: 132 378 649 rub
#  37 | 37 page with list: [=>=>                                                    ] 8% | Count of all parsed: 344. Progress ratio: 13 %. Average price: 131 353 937 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 37 page...
#
# Average price per day: 131 016 855 rub
#
#  38 page: 28 offers
#  38 | 38 page with list: [=>                                                      ] 4% | Count of all parsed: 347. Progress ratio: 13 %. Average price: 130 351 917 rub
#  38 | 38 page with list: [=>=>                                                    ] 8% | Count of all parsed: 350. Progress ratio: 13 %. Average price: 129 368 977 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 38 page...
#
# Average price per day: 129 045 116 rub
#
#  39 page: 28 offers
#  39 | 39 page with list: [=>                                                      ] 4% | Count of all parsed: 353. Progress ratio: 13 %. Average price: 128 407 392 rub
#  39 | 39 page with list: [=>=>                                                    ] 8% | Count of all parsed: 356. Progress ratio: 13 %. Average price: 127 463 941 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 39 page...
#
# Average price per day: 127 153 654 rub
#
#  40 page: 28 offers
#  40 | 40 page with list: [=>                                                      ] 4% | Count of all parsed: 359. Progress ratio: 13 %. Average price: 126 544 376 rub
#  40 | 40 page with list: [=>=>                                                    ] 8% | Count of all parsed: 362. Progress ratio: 13 %. Average price: 125 643 015 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 40 page...
#
# Average price per day: 125 346 138 rub
#
#  41 page: 28 offers
#  41 | 41 page with list: [=>                                                      ] 4% | Count of all parsed: 365. Progress ratio: 14 %. Average price: 124 762 845 rub
#  41 | 41 page with list: [=>=>                                                    ] 8% | Count of all parsed: 368. Progress ratio: 14 %. Average price: 123 900 491 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 41 page...
#
# Average price per day: 123 616 072 rub
#
#  42 page: 28 offers
#  42 | 42 page with list: [=>                                                      ] 4% | Count of all parsed: 371. Progress ratio: 14 %. Average price: 123 056 737 rub
#  42 | 42 page with list: [=>=>                                                    ] 8% | Count of all parsed: 374. Progress ratio: 14 %. Average price: 122 228 632 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 42 page...
#
# Average price per day: 121 955 527 rub
#
#  43 page: 28 offers
#  43 | 43 page with list: [=>                                                      ] 4% | Count of all parsed: 377. Progress ratio: 14 %. Average price: 121 421 341 rub
#  43 | 43 page with list: [=>=>                                                    ] 8% | Count of all parsed: 380. Progress ratio: 14 %. Average price: 120 630 747 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 43 page...
#
# Average price per day: 120 370 237 rub
#
#  44 page: 28 offers
#  44 | 44 page with list: [=>                                                      ] 4% | Count of all parsed: 383. Progress ratio: 14 %. Average price: 119 864 037 rub
#  44 | 44 page with list: [=>=>                                                    ] 8% | Count of all parsed: 386. Progress ratio: 14 %. Average price: 119 115 060 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 44 page...
#
# Average price per day: 118 868 303 rub
#
#  45 page: 28 offers
#  45 | 45 page with list: [=>                                                      ] 4% | Count of all parsed: 389. Progress ratio: 14 %. Average price: 118 387 747 rub
#  45 | 45 page with list: [=>=>                                                    ] 8% | Count of all parsed: 392. Progress ratio: 14 %. Average price: 117 677 757 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 45 page...
#
# Average price per day: 117 443 949 rub
#
#  46 page: 28 offers
#  46 | 46 page with list: [=>                                                      ] 4% | Count of all parsed: 395. Progress ratio: 15 %. Average price: 116 993 341 rub
#  46 | 46 page with list: [=>=>                                                    ] 8% | Count of all parsed: 398. Progress ratio: 15 %. Average price: 116 327 217 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 46 page...
#
# Average price per day: 116 107 663 rub
#
#  47 page: 28 offers
#  47 | 47 page with list: [=>                                                      ] 4% | Count of all parsed: 401. Progress ratio: 15 %. Average price: 115 689 403 rub
#  47 | 47 page with list: [=>=>                                                    ] 8% | Count of all parsed: 404. Progress ratio: 15 %. Average price: 115 071 632 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 47 page...
#
# Average price per day: 114 868 469 rub
#
#  48 page: 28 offers
#  48 | 48 page with list: [=>                                                      ] 4% | Count of all parsed: 407. Progress ratio: 15 %. Average price: 114 477 076 rub
#  48 | 48 page with list: [=>=>                                                    ] 8% | Count of all parsed: 410. Progress ratio: 15 %. Average price: 113 897 880 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 48 page...
#
# Average price per day: 113 707 055 rub
#
#  49 page: 28 offers
#  49 | 49 page with list: [=>                                                      ] 4% | Count of all parsed: 413. Progress ratio: 15 %. Average price: 113 338 223 rub
#  49 | 49 page with list: [=>=>                                                    ] 8% | Count of all parsed: 416. Progress ratio: 15 %. Average price: 112 793 055 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 49 page...
#
# Average price per day: 112 613 377 rub
#
#  50 page: 28 offers
#  50 | 50 page with list: [=>                                                      ] 4% | Count of all parsed: 419. Progress ratio: 15 %. Average price: 112 266 774 rub
#  50 | 50 page with list: [=>=>                                                    ] 8% | Count of all parsed: 422. Progress ratio: 16 %. Average price: 111 756 015 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 50 page...
#
# Average price per day: 111 587 862 rub
#
#  51 page: 28 offers
#  51 | 51 page with list: [=>                                                      ] 4% | Count of all parsed: 425. Progress ratio: 16 %. Average price: 111 267 452 rub
#  51 | 51 page with list: [=>=>                                                    ] 8% | Count of all parsed: 428. Progress ratio: 16 %. Average price: 110 793 555 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 51 page...
#
# Average price per day: 110 637 558 rub
#
#  52 page: 28 offers
#  52 | 52 page with list: [=>                                                      ] 4% | Count of all parsed: 431. Progress ratio: 16 %. Average price: 110 338 322 rub
#  52 | 52 page with list: [=>=>                                                    ] 8% | Count of all parsed: 434. Progress ratio: 16 %. Average price: 109 894 765 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 52 page...
#
# Average price per day: 109 748 889 rub
#
#  53 page: 28 offers
#  53 | 53 page with list: [=>                                                      ] 4% | Count of all parsed: 437. Progress ratio: 16 %. Average price: 109 471 049 rub
#  53 | 53 page with list: [=>=>                                                    ] 8% | Count of all parsed: 440. Progress ratio: 16 %. Average price: 109 059 728 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 53 page...
#
# Average price per day: 108 924 430 rub
#
#  54 page: 25 offers
#  54 | 54 page with list: [=>                                                ] 4% | Count of all parsed: 443. Progress ratio: 18 %. Average price: 108 670 550 rub
#  54 | 54 page with list: [=>=>                                              ] 8% | Count of all parsed: 446. Progress ratio: 18 %. Average price: 108 292 384 rub
#
# Exception: 'charmap' codec can't encode character '\xc1' in position 255: character maps to <undefined>
# The collection of information from the pages with ending parse on 54 page...
#
# Average price per day: 108 169 003 rub
#
#  55 | 55 page: cian is redirecting from page 55 to page 1... there is maximum value of page, you should try to decrease number of page... ending...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 447. Average price: 108 169 003 rub

# %%
data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location = "Москва",
    rooms=5,
    is_saving_csv=True,
    is_latin=False,
    is_express_mode=False,
)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_moskva_07_Jan_2024_07_37_48_163824.csv
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=1&offer_type=flat&deal_type=sale&room5=1&with_neighbors=0
# Collecting information from pages with list of announcements
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 276 314 962 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 2 %. Average price: 221 119 700 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 3 %. Average price: 205 281 358 rub
#  4 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 112. Progress ratio: 4 %. Average price: 255 659 450 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 140. Progress ratio: 5 %. Average price: 292 211 314 rub
#  6 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 168. Progress ratio: 6 %. Average price: 301 936 782 rub
#  7 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 196. Progress ratio: 7 %. Average price: 288 370 750 rub
#  8 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 224. Progress ratio: 8 %. Average price: 271 103 702 rub
#  9 | 9 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 252. Progress ratio: 9 %. Average price: 257 725 795 rub
#  10 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 280. Progress ratio: 10 %. Average price: 249 278 657 rub
#  11 | 11 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 308. Progress ratio: 11 %. Average price: 242 565 528 rub
#  12 | 12 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 336. Progress ratio: 12 %. Average price: 237 347 069 rub
#  13 | 13 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 364. Progress ratio: 13 %. Average price: 240 259 858 rub
#  14 | 14 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 392. Progress ratio: 14 %. Average price: 242 532 694 rub
#  15 | 15 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 420. Progress ratio: 15 %. Average price: 243 351 271 rub
#  16 | 16 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 448. Progress ratio: 16 %. Average price: 259 092 494 rub
#  17 | 17 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 476. Progress ratio: 17 %. Average price: 247 098 141 rub
#  18 | 18 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 504. Progress ratio: 18 %. Average price: 237 886 358 rub
#  19 | 19 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 532. Progress ratio: 19 %. Average price: 231 742 786 rub
#  20 | 20 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 560. Progress ratio: 20 %. Average price: 229 483 701 rub
#  21 | 21 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 588. Progress ratio: 21 %. Average price: 238 875 424 rub
#  22 | 22 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 616. Progress ratio: 22 %. Average price: 250 279 460 rub
#  23 | 23 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 644. Progress ratio: 23 %. Average price: 245 748 867 rub
#  24 | 24 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 672. Progress ratio: 24 %. Average price: 236 664 940 rub
#  25 | 25 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 700. Progress ratio: 25 %. Average price: 228 929 626 rub
#  26 | 26 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 728. Progress ratio: 26 %. Average price: 222 233 083 rub
#  27 | 27 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 755. Progress ratio: 28 %. Average price: 216 538 095 rub
#  28 | 28 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 783. Progress ratio: 28 %. Average price: 211 284 316 rub
#  29 | 29 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 811. Progress ratio: 29 %. Average price: 206 629 917 rub
#  30 | 30 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 839. Progress ratio: 30 %. Average price: 202 499 562 rub
#  31 | 31 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 866. Progress ratio: 33 %. Average price: 198 953 232 rub
#  32 | 32 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 894. Progress ratio: 32 %. Average price: 195 730 425 rub
#  33 | 33 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 922. Progress ratio: 33 %. Average price: 193 118 167 rub
#  34 | 34 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 948. Progress ratio: 37 %. Average price: 191 187 792 rub
#  35 | 35 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 974. Progress ratio: 38 %. Average price: 189 671 482 rub
#  36 | 36 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1002. Progress ratio: 36 %. Average price: 188 513 497 rub
#  37 | 37 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1027. Progress ratio: 42 %. Average price: 187 716 383 rub
#  38 | 38 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1053. Progress ratio: 41 %. Average price: 187 365 780 rub
#  39 | 39 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1079. Progress ratio: 42 %. Average price: 187 262 225 rub
#  40 | 40 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1106. Progress ratio: 41 %. Average price: 187 631 107 rub
#  41 | 41 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1131. Progress ratio: 46 %. Average price: 188 712 937 rub
#  42 | 42 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1159. Progress ratio: 42 %. Average price: 190 170 804 rub
#  43 | 43 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1186. Progress ratio: 44 %. Average price: 191 803 949 rub
#  44 | 44 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1213. Progress ratio: 45 %. Average price: 194 170 503 rub
#  45 | 45 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1240. Progress ratio: 46 %. Average price: 197 385 197 rub
#  46 | 46 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1266. Progress ratio: 49 %. Average price: 201 163 281 rub
#  47 | 47 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1294. Progress ratio: 47 %. Average price: 206 420 741 rub
#  48 | 48 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1319. Progress ratio: 53 %. Average price: 213 672 201 rub
#  49 | 49 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1347. Progress ratio: 49 %. Average price: 219 496 653 rub
#  50 | 50 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1375. Progress ratio: 50 %. Average price: 215 666 727 rub
#  51 | 51 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1403. Progress ratio: 51 %. Average price: 212 215 923 rub
#  52 | 52 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1431. Progress ratio: 52 %. Average price: 209 189 571 rub
#  53 | 53 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1458. Progress ratio: 54 %. Average price: 206 679 378 rub
#  54 | 54 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 1483. Progress ratio: 60 %. Average price: 204 539 742 rub
#  55 | 55 page: cian is redirecting from page 55 to page 1... there is maximum value of page, you should try to decrease number of page... ending...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 1483. Average price: 204 539 742 rub

# %%
data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location = "Химки",
    rooms=1,
    is_saving_csv=True,
    is_latin=False,
    is_express_mode=False,
)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_himki_07_Jan_2024_16_55_57_542223.csv
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=5044&offer_type=flat&deal_type=sale&room1=1&with_neighbors=0
# Collecting information from pages with list of announcements
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 8 490 069 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 2 %. Average price: 8 185 502 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 3 %. Average price: 8 231 769 rub
#  4 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 112. Progress ratio: 4 %. Average price: 7 919 612 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 140. Progress ratio: 5 %. Average price: 7 713 068 rub
#  6 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 168. Progress ratio: 6 %. Average price: 7 832 048 rub
#  7 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 196. Progress ratio: 7 %. Average price: 8 003 735 rub
#  8 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 224. Progress ratio: 8 %. Average price: 7 958 973 rub
#  9 | 9 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 252. Progress ratio: 9 %. Average price: 8 024 555 rub
#  10 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 280. Progress ratio: 10 %. Average price: 8 088 310 rub
#  11 | 11 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 308. Progress ratio: 11 %. Average price: 8 085 202 rub
#  12 | 12 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 336. Progress ratio: 12 %. Average price: 8 170 034 rub
#  13 | 13 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 364. Progress ratio: 13 %. Average price: 8 260 938 rub
#  14 | 14 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 392. Progress ratio: 14 %. Average price: 8 274 970 rub
#  15 | 15 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 420. Progress ratio: 15 %. Average price: 8 199 851 rub
#  16 | 16 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 89% | Count of all parsed: 444. Progress ratio: 17 %. Average price: 8 133 943 rub
#  16 | 16 page with list: [=>=>                                                  ] 8% | Count of all parsed: 446. Progress ratio: 17 %. Average price: 8 127 961 rub
#  16 | 16 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 473. Progress ratio: 18 %. Average price: 8 063 222 rub
#  17 | 17 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 500. Progress ratio: 19 %. Average price: 8 020 186 rub
#  18 | 18 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 527. Progress ratio: 20 %. Average price: 7 998 526 rub
#  19 | 19 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 555. Progress ratio: 20 %. Average price: 7 995 654 rub
#  20 | 20 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 583. Progress ratio: 21 %. Average price: 8 008 525 rub
#  21 | 21 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 611. Progress ratio: 22 %. Average price: 8 035 925 rub
#  22 | 22 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 639. Progress ratio: 23 %. Average price: 8 083 083 rub
#  23 | 23 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 667. Progress ratio: 24 %. Average price: 8 158 700 rub
#  24 | 24 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 695. Progress ratio: 25 %. Average price: 8 269 814 rub
#  25 | 25 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 723. Progress ratio: 26 %. Average price: 8 469 101 rub
#  26 | 26 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 748. Progress ratio: 30 %. Average price: 8 521 575 rub
#  27 | 27 page: cian is redirecting from page 27 to page 1... there is maximum value of page, you should try to decrease number of page... ending...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 748. Average price: 8 521 575 rub

# %%
data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location = "Химки",
    rooms=2,
    is_saving_csv=True,
    is_latin=False,
    is_express_mode=False,
)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_himki_07_Jan_2024_17_53_27_956194.csv
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=5044&offer_type=flat&deal_type=sale&room2=1&with_neighbors=0
# Collecting information from pages with list of announcements
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 9 344 582 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 2 %. Average price: 10 357 337 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 3 %. Average price: 10 296 646 rub
#  4 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 112. Progress ratio: 4 %. Average price: 10 038 581 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 140. Progress ratio: 5 %. Average price: 10 005 734 rub
#  6 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 168. Progress ratio: 6 %. Average price: 10 193 121 rub
#  7 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 196. Progress ratio: 7 %. Average price: 10 204 682 rub
#  8 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 224. Progress ratio: 8 %. Average price: 10 255 039 rub
#  9 | 9 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 252. Progress ratio: 9 %. Average price: 10 500 786 rub
#  10 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 280. Progress ratio: 10 %. Average price: 10 504 633 rub
#  11 | 11 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 308. Progress ratio: 11 %. Average price: 10 487 293 rub
#  12 | 12 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 336. Progress ratio: 12 %. Average price: 10 588 470 rub
#  13 | 13 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 364. Progress ratio: 13 %. Average price: 10 738 780 rub
#  14 | 14 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 392. Progress ratio: 14 %. Average price: 10 907 388 rub
#  15 | 15 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 420. Progress ratio: 15 %. Average price: 10 924 163 rub
#  16 | 16 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 448. Progress ratio: 16 %. Average price: 11 052 514 rub
#  17 | 17 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 476. Progress ratio: 17 %. Average price: 11 211 526 rub
#  18 | 18 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 504. Progress ratio: 18 %. Average price: 11 470 753 rub
#  19 | 19 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 532. Progress ratio: 19 %. Average price: 11 825 008 rub
#  20 | 20 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 560. Progress ratio: 20 %. Average price: 11 572 892 rub
#  21 | 21 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 588. Progress ratio: 21 %. Average price: 11 387 672 rub
#  22 | 22 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 616. Progress ratio: 22 %. Average price: 11 247 794 rub
#  23 | 23 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 644. Progress ratio: 23 %. Average price: 11 150 308 rub
#  24 | 24 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 671. Progress ratio: 25 %. Average price: 11 090 736 rub
#  25 | 25 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 699. Progress ratio: 25 %. Average price: 11 058 062 rub
#  26 | 26 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 727. Progress ratio: 26 %. Average price: 11 056 577 rub
#  27 | 27 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 755. Progress ratio: 27 %. Average price: 11 074 568 rub
#  28 | 28 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 783. Progress ratio: 28 %. Average price: 11 116 639 rub
#  29 | 29 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 811. Progress ratio: 29 %. Average price: 11 186 327 rub
#  30 | 30 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 839. Progress ratio: 30 %. Average price: 11 284 605 rub
#  31 | 31 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 866. Progress ratio: 33 %. Average price: 11 442 521 rub
#  32 | 32 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 894. Progress ratio: 32 %. Average price: 11 557 724 rub
#  33 | 33 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 919. Progress ratio: 37 %. Average price: 11 578 584 rub
#  34 | 34 page: cian is redirecting from page 34 to page 1... there is maximum value of page, you should try to decrease number of page... ending...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 919. Average price: 11 578 584 rub

# %%
data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location = "Химки",
    rooms=3,
    is_saving_csv=True,
    is_latin=False,
    is_express_mode=False,
)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_himki_07_Jan_2024_19_04_15_882177.csv
#
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 13 901 718 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 2 %. Average price: 14 552 962 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 3 %. Average price: 14 106 766 rub
#  4 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 112. Progress ratio: 4 %. Average price: 14 096 845 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 140. Progress ratio: 5 %. Average price: 14 152 190 rub
#  6 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 168. Progress ratio: 6 %. Average price: 14 429 569 rub
#  7 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 196. Progress ratio: 7 %. Average price: 14 386 865 rub
#  8 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 224. Progress ratio: 8 %. Average price: 14 722 610 rub
#  9 | 9 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 252. Progress ratio: 9 %. Average price: 15 139 953 rub
#  10 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 280. Progress ratio: 10 %. Average price: 15 150 399 rub
#  11 | 11 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 308. Progress ratio: 11 %. Average price: 15 548 187 rub
#  12 | 12 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 336. Progress ratio: 12 %. Average price: 15 408 109 rub
#  13 | 13 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 364. Progress ratio: 13 %. Average price: 15 363 744 rub
#  14 | 14 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 392. Progress ratio: 14 %. Average price: 15 179 902 rub
#  15 | 15 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 420. Progress ratio: 15 %. Average price: 15 025 978 rub
#  16 | 16 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 448. Progress ratio: 16 %. Average price: 15 024 540 rub
#  17 | 17 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 476. Progress ratio: 17 %. Average price: 15 136 033 rub
#  18 | 18 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 504. Progress ratio: 18 %. Average price: 15 390 247 rub
#  19 | 19 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 532. Progress ratio: 19 %. Average price: 16 076 078 rub
#  20 | 20 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 557. Progress ratio: 23 %. Average price: 16 253 820 rub
#  21 | 21 page: cian is redirecting from page 21 to page 1... there is maximum value of page, you should try to decrease number of page... ending...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 557. Average price: 16 253 820 rub

# %%
data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location = "Химки",
    rooms=4,
    is_saving_csv=True,
    is_latin=False,
    is_express_mode=False,
)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_himki_07_Jan_2024_19_47_28_417244.csv
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=5044&offer_type=flat&deal_type=sale&room4=1&with_neighbors=0
# Collecting information from pages with list of announcements
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 18 575 070 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 2 %. Average price: 25 659 499 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 3 %. Average price: 25 060 499 rub
#  4 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 109. Progress ratio: 5 %. Average price: 24 875 522 rub
#  5 | 5 page: cian is redirecting from page 5 to page 1... there is maximum value of page, you should try to decrease number of page... ending...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 109. Average price: 24 875 522 rub

# %%
data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location = "Химки",
    rooms=5,
    is_saving_csv=True,
    is_latin=False,
    is_express_mode=False,
)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_himki_07_Jan_2024_19_55_51_491139.csv
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=5044&offer_type=flat&deal_type=sale&room5=1&with_neighbors=0
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 0. Average price: 0 rub

# %%
cities = ['Домодедово'] #'Балашиха','Люберцы','Красногорск','Видное','Котельники',
for city in cities:
    for room in range(1,6):
        data = cianparser.parse(
            deal_type="sale",
            accommodation_type="flat",
            location = city,
            rooms=room,
            is_saving_csv=True,
            is_latin=False,
            is_express_mode=False,
        )
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_domodedovo_08_Jan_2024_06_50_45_251963.csv
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=174640&offer_type=flat&deal_type=sale&room1=1&with_neighbors=0
# Collecting information from pages with list of announcements
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 6 189 431 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 2 %. Average price: 6 078 608 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 3 %. Average price: 6 086 429 rub
#  4 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 112. Progress ratio: 4 %. Average price: 6 269 420 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 140. Progress ratio: 5 %. Average price: 6 302 243 rub
#  6 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 168. Progress ratio: 6 %. Average price: 6 291 685 rub
#  7 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 196. Progress ratio: 7 %. Average price: 6 337 572 rub
#  8 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 224. Progress ratio: 8 %. Average price: 6 307 112 rub
#  9 | 9 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 252. Progress ratio: 9 %. Average price: 6 338 465 rub
#  10 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 277. Progress ratio: 12 %. Average price: 6 352 040 rub
#  11 | 11 page: cian is redirecting from page 11 to page 1... there is maximum value of page, you should try to decrease number of page... ending...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 277. Average price: 6 352 040 rub
#
#
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_domodedovo_08_Jan_2024_07_11_39_085727.csv
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=174640&offer_type=flat&deal_type=sale&room2=1&with_neighbors=0
# Collecting information from pages with list of announcements
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 8 973 392 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 2 %. Average price: 8 285 539 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 3 %. Average price: 8 241 883 rub
#  4 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 112. Progress ratio: 4 %. Average price: 8 244 171 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 140. Progress ratio: 5 %. Average price: 8 343 051 rub
#  6 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 168. Progress ratio: 6 %. Average price: 8 475 453 rub
#  7 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 196. Progress ratio: 7 %. Average price: 8 633 128 rub
#  8 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 224. Progress ratio: 8 %. Average price: 8 516 777 rub
#  9 | 9 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 252. Progress ratio: 9 %. Average price: 8 514 195 rub
#  10 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 280. Progress ratio: 10 %. Average price: 8 470 668 rub
#  11 | 11 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 305. Progress ratio: 13 %. Average price: 8 420 505 rub
#  12 | 12 page: cian is redirecting from page 12 to page 1... there is maximum value of page, you should try to decrease number of page... ending...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 305. Average price: 8 420 505 rub
#
#
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_domodedovo_08_Jan_2024_07_34_55_807384.csv
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=174640&offer_type=flat&deal_type=sale&room3=1&with_neighbors=0
# Collecting information from pages with list of announcements
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 9 943 909 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 2 %. Average price: 10 175 526 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 3 %. Average price: 10 491 041 rub
#  4 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 112. Progress ratio: 4 %. Average price: 10 617 495 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 140. Progress ratio: 5 %. Average price: 10 678 924 rub
#  6 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 168. Progress ratio: 6 %. Average price: 10 702 455 rub
#  7 | 7 page: cian is redirecting from page 7 to page 1... there is maximum value of page, you should try to decrease number of page... ending...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 168. Average price: 10 702 455 rub
#
#
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_domodedovo_08_Jan_2024_07_47_39_233903.csv
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=174640&offer_type=flat&deal_type=sale&room4=1&with_neighbors=0
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 0. Average price: 0 rub
#
#
#                               Preparing to collect information from pages..
# The absolute path to the file:
# D:\Github proj\MachineLearning\ML\Teacher\samolet\cian_parsing_result_sale_1_100_domodedovo_08_Jan_2024_07_47_40_939903.csv
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=174640&offer_type=flat&deal_type=sale&room5=1&with_neighbors=0
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 0. Average price: 0 rub
