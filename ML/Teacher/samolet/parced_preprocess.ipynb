# %%
import numpy as np
import pandas as pd
# Balashiha
df1 = pd.read_csv('cian_parsing_result_sale_1_100_balashiha_07_Jan_2024_20_49_53_039400.csv',encoding='cp1251',sep=';')
df2 = pd.read_csv('cian_parsing_result_sale_1_100_balashiha_07_Jan_2024_22_26_40_460026.csv', encoding='cp1251',sep=';')
df3 = pd.read_csv('cian_parsing_result_sale_1_100_balashiha_08_Jan_2024_00_04_53_434867.csv', encoding='cp1251',sep=';')
df4 = pd.read_csv('cian_parsing_result_sale_1_100_balashiha_08_Jan_2024_01_00_28_751451.csv', encoding='cp1251',sep=';')

df_bal = pd.concat([df1,df2,df3,df4],axis=0)
df_bal
# Out:
#                        author               author_type  \
# 0                         ПИК                 developer
# 1                   ФСК Агент         real_estate_agent
# 2        Абсолют Недвижимость  representative_developer
# 3                Этажи Москва         real_estate_agent
# 4          СЕТЬСТРОЙ БАЛАШИХА                 developer
# ..                        ...                       ...
# 75                ID 58386972                 homeowner
# 76                ID 70079595                 homeowner
# 77         СЕТЬСТРОЙ БАЛАШИХА                 developer
# 78  Недвижимость на Советской         real_estate_agent
# 79         СЕТЬСТРОЙ БАЛАШИХА                 developer
#
#                                                link      city deal_type  \
# 0   https://balashikha.cian.ru/sale/flat/295120742/  Балашиха      sale
# 1   https://balashikha.cian.ru/sale/flat/294969565/  Балашиха      sale
# 2   https://balashikha.cian.ru/sale/flat/296875187/  Балашиха      sale
# ...

# %%
# Dolgoprudnyj
df1 = pd.read_csv('cian_parsing_result_sale_1_100_dolgoprudnyj_07_Jan_2024_16_02_36_124694.csv', encoding='cp1251',sep=';')
df2 = pd.read_csv('cian_parsing_result_sale_1_100_dolgoprudnyj_07_Jan_2024_16_17_30_501153.csv', encoding='cp1251', sep=';')
df3 = pd.read_csv('cian_parsing_result_sale_1_100_dolgoprudnyj_07_Jan_2024_16_38_57_070681.csv', encoding='cp1251', sep=';')

df_dol = pd.concat([df1,df2,df3],axis=0)
df_dol
# Out:
#                  author        author_type  \
# 0                   NaN                NaN
# 1          Этажи Москва  real_estate_agent
# 2                   NaN                NaN
# 3          Этажи Москва  real_estate_agent
# 4    Городские квартиры  real_estate_agent
# ..                  ...                ...
# 106              Владис  real_estate_agent
# 107           ID 177294            unknown
# 108         ID 95922805            realtor
# 109         ID 64963805          homeowner
# 110         ID 30681259          homeowner
#
#                                                  link          city deal_type  \
# 0    https://dolgoprudny.cian.ru/sale/flat/295106795/  Долгопрудный      sale
# 1    https://dolgoprudny.cian.ru/sale/flat/296958970/  Долгопрудный      sale
# 2    https://dolgoprudny.cian.ru/sale/flat/294460553/  Долгопрудный      sale
# 3    https://dolgoprudny.cian.ru/sale/flat/296958983/  Долгопрудный      sale
# ...

# %%
# Domodedovo
df1 = pd.read_csv('cian_parsing_result_sale_1_100_domodedovo_08_Jan_2024_06_50_45_251963.csv', encoding='cp1251', sep=';')
df2 = pd.read_csv('cian_parsing_result_sale_1_100_domodedovo_08_Jan_2024_07_11_39_085727.csv', encoding='cp1251', sep=';')
df3 = pd.read_csv('cian_parsing_result_sale_1_100_domodedovo_08_Jan_2024_07_34_55_807384.csv', encoding='cp1251', sep=';')

df_dom = pd.concat([df1,df2,df3])
df_dom
# Out:
#                            author               author_type  \
# 0    НДВ Супермаркет Недвижимости  representative_developer
# 1                    ЕГСН Продажа         real_estate_agent
# 2    НДВ Супермаркет Недвижимости  representative_developer
# 3     Alliance Agency Real Estate         real_estate_agent
# 4    НДВ Супермаркет Недвижимости  representative_developer
# ..                            ...                       ...
# 163                   ID 98697321                 homeowner
# 164                   ID 19488344                   realtor
# 165                  ID 109930927                 homeowner
# 166                  ID 109931434                 homeowner
# 167                  ID 105705812                 homeowner
#
#                                                 link        city deal_type  \
# 0    https://domodedovo.cian.ru/sale/flat/293133124/  Домодедово      sale
# 1    https://domodedovo.cian.ru/sale/flat/295993670/  Домодедово      sale
# ...

# %%
# Himki
df1 = pd.read_csv('cian_parsing_result_sale_1_100_himki_07_Jan_2024_16_55_57_542223.csv', encoding='cp1251', sep=';')
df2 = pd.read_csv('cian_parsing_result_sale_1_100_himki_07_Jan_2024_17_53_27_956194.csv', encoding='cp1251', sep=';')
df3 = pd.read_csv('cian_parsing_result_sale_1_100_himki_07_Jan_2024_19_04_15_882177.csv', encoding='cp1251', sep=';')
df4 = pd.read_csv('cian_parsing_result_sale_1_100_himki_07_Jan_2024_19_47_28_417244.csv', encoding='cp1251', sep=';')

df_him = pd.concat([df1,df2,df3,df4])
df_him
# Out:
#                  author              author_type  \
# 0                 ДСК-1                developer
# 1          Этажи Москва        real_estate_agent
# 2                 ДСК-1                developer
# 3              ИМПЕРИАЛ  official_representative
# 4              ЖилСтрой                developer
# ..                  ...                      ...
# 101         ID 79506958                  realtor
# 102  Городские квартиры        real_estate_agent
# 103              Владис        real_estate_agent
# 104          Уютный Дом        real_estate_agent
# 105             Homeapp        real_estate_agent
#
#                                             link   city deal_type  \
# 0    https://khimki.cian.ru/sale/flat/296810711/  Химки      sale
# 1    https://khimki.cian.ru/sale/flat/292509520/  Химки      sale
# 2    https://khimki.cian.ru/sale/flat/296810741/  Химки      sale
# 3    https://khimki.cian.ru/sale/flat/295623322/  Химки      sale
# ...

# %%
# Krasnogorsk
df1 = pd.read_csv('cian_parsing_result_sale_1_100_krasnogorsk_08_Jan_2024_03_41_35_898297.csv', encoding='cp1251', sep=';')
df2 = pd.read_csv('cian_parsing_result_sale_1_100_krasnogorsk_08_Jan_2024_04_21_45_041732.csv', encoding='cp1251', sep=';')
df3 = pd.read_csv('cian_parsing_result_sale_1_100_krasnogorsk_08_Jan_2024_05_11_20_636360.csv', encoding='cp1251', sep=';')
df4 = pd.read_csv('cian_parsing_result_sale_1_100_krasnogorsk_08_Jan_2024_05_43_15_589155.csv', encoding='cp1251', sep=';')

df_kra = pd.concat([df1,df2,df3,df4])
df_kra
# Out:
#             author        author_type  \
# 0   Садовое кольцо          developer
# 1       LaRichesse  real_estate_agent
# 2   Садовое кольцо          developer
# 3     ЕГСН Продажа  real_estate_agent
# 4   Садовое кольцо          developer
# ..             ...                ...
# 48     ID 22102233          homeowner
# 49    ID 107172632          homeowner
# 50     ID 59570362          homeowner
# 51      EstateLiga  real_estate_agent
# 52     ID 55673680          homeowner
#
#                                                 link         city deal_type  \
# 0   https://krasnogorsk.cian.ru/sale/flat/294552128/  Красногорск      sale
# 1   https://krasnogorsk.cian.ru/sale/flat/296962629/  Красногорск      sale
# 2   https://krasnogorsk.cian.ru/sale/flat/293271517/  Красногорск      sale
# 3   https://krasnogorsk.cian.ru/sale/flat/274781081/  Красногорск      sale
# 4   https://krasnogorsk.cian.ru/sale/flat/296871436/  Красногорск      sale
# ...

# %%
# Ljubertsy
df1 = pd.read_csv('cian_parsing_result_sale_1_100_ljubertsy_08_Jan_2024_01_06_47_623136.csv', encoding='cp1251', sep=';')
df2 = pd.read_csv('cian_parsing_result_sale_1_100_ljubertsy_08_Jan_2024_02_03_15_072809.csv', encoding='cp1251', sep=';')
df3 = pd.read_csv('cian_parsing_result_sale_1_100_ljubertsy_08_Jan_2024_03_00_05_320649.csv', encoding='cp1251', sep=';')
df4 = pd.read_csv('cian_parsing_result_sale_1_100_ljubertsy_08_Jan_2024_03_35_02_871457.csv', encoding='cp1251', sep=';')

df_lju = pd.concat([df1,df2,df3,df4])
df_lju
# Out:
#                   author               author_type  \
# 0                  ДСК-1                 developer
# 1           ЕГСН Продажа         real_estate_agent
# 2   Абсолют Недвижимость  representative_developer
# 3           ЕГСН Продажа         real_estate_agent
# 4                  ДСК-1                 developer
# ..                   ...                       ...
# 74                   ПИК                 developer
# 75    Magnum Development                 developer
# 76    Magnum Development                 developer
# 77           ID 97579832                 homeowner
# 78                Основа                 developer
#
#                                               link     city deal_type  \
# 0   https://lyubertsy.cian.ru/sale/flat/296597091/  Люберцы      sale
# 1   https://lyubertsy.cian.ru/sale/flat/292773093/  Люберцы      sale
# 2   https://lyubertsy.cian.ru/sale/flat/296464858/  Люберцы      sale
# ...

# %%
# Moscow
df1 = pd.read_csv('cian_parsing_result_sale_1_100_moskva_07_Jan_2024_05_08_02_980059.csv', encoding='cp1251', sep=';')
df2 = pd.read_csv('cian_parsing_result_sale_1_100_moskva_07_Jan_2024_05_52_56_834447.csv', encoding='cp1251', sep=';')
df3 = pd.read_csv('cian_parsing_result_sale_1_100_moskva_07_Jan_2024_06_35_53_932296.csv', encoding='cp1251', sep=';')
df4 = pd.read_csv('cian_parsing_result_sale_1_100_moskva_07_Jan_2024_07_11_05_189339.csv', encoding='cp1251', sep=';')
df5 = pd.read_csv('cian_parsing_result_sale_1_100_moskva_07_Jan_2024_07_37_48_163824.csv', encoding='cp1251', sep=';')

df_mos = pd.concat([df1, df2, df3, df4, df5])
df_mos
# Out:
#                    author        author_type  \
# 0                MR Group          developer
# 1         Business Leader  real_estate_agent
# 2           Sminex-Интеко          developer
# 3     White and Broughton  real_estate_agent
# 4           Sminex-Интеко          developer
# ...                   ...                ...
# 1372              Спутник  real_estate_agent
# 1373       Квартал Риэлти  real_estate_agent
# 1374          ID 12563881            unknown
# 1375            Whitewill  real_estate_agent
# 1376       Premium Realty  real_estate_agent
#
#                                           link    city deal_type  \
# 0     https://www.cian.ru/sale/flat/292125772/  Москва      sale
# 1     https://www.cian.ru/sale/flat/296959546/  Москва      sale
# 2     https://www.cian.ru/sale/flat/296140196/  Москва      sale
# 3     https://www.cian.ru/sale/flat/290499455/  Москва      sale
# 4     https://www.cian.ru/sale/flat/293713671/  Москва      sale
# ...

# %%
# Vidnoe
df1 = pd.read_csv('cian_parsing_result_sale_1_100_vidnoe_08_Jan_2024_05_47_22_077110.csv', encoding='cp1251', sep=';')
df2 = pd.read_csv('cian_parsing_result_sale_1_100_vidnoe_08_Jan_2024_06_10_36_612361.csv', encoding='cp1251', sep=';')
df3 = pd.read_csv('cian_parsing_result_sale_1_100_vidnoe_08_Jan_2024_06_35_53_073848.csv',encoding='cp1251', sep=';')

df_vid = pd.concat([df1, df2, df3])
df_vid
# Out:
#               author        author_type  \
# 0              ДСК-1          developer
# 1    Business Leader  real_estate_agent
# 2              ДСК-1          developer
# 3        Суламит-НГС  real_estate_agent
# 4              ДСК-1          developer
# ..               ...                ...
# 160     ID 105075707          homeowner
# 161     Самолет Плюс  real_estate_agent
# 162        ID 142392            realtor
# 163      ID 57136041          homeowner
# 164     ID 102350615          homeowner
#
#                                              link    city deal_type  \
# 0    https://vidnoye.cian.ru/sale/flat/296705420/  Видное      sale
# 1    https://vidnoye.cian.ru/sale/flat/295191863/  Видное      sale
# 2    https://vidnoye.cian.ru/sale/flat/296705410/  Видное      sale
# 3    https://vidnoye.cian.ru/sale/flat/296244304/  Видное      sale
# 4    https://vidnoye.cian.ru/sale/flat/292277054/  Видное      sale
# ...

# %%
df_all = pd.concat([df_mos, df_vid, df_lju, df_him, df_bal, df_dom, df_dol, df_kra]).replace(-1,np.nan)
df_preprocessed = df_all.loc[df_all['object_type'] == 'Вторичка'].drop(columns=['object_type','house_material_type','heating_type','finish_type','house_number'])
df_preprocessed
# Out:
#                       author        author_type  \
# 1            Business Leader  real_estate_agent
# 3        White and Broughton  real_estate_agent
# 5        White and Broughton  real_estate_agent
# 7   Century 21 Street Realty  real_estate_agent
# 9   Century 21 Street Realty  real_estate_agent
# ..                       ...                ...
# 47               ID 44045003          homeowner
# 48               ID 22102233          homeowner
# 49              ID 107172632          homeowner
# 50               ID 59570362          homeowner
# 52               ID 55673680          homeowner
#
#                                                 link         city deal_type  \
# 1           https://www.cian.ru/sale/flat/296959546/       Москва      sale
# 3           https://www.cian.ru/sale/flat/290499455/       Москва      sale
# 5           https://www.cian.ru/sale/flat/292933473/       Москва      sale
# 7           https://www.cian.ru/sale/flat/295666816/       Москва      sale
# ...

# %%
df_preprocessed.to_csv('cian_parced.csv', index=False)

# %% [markdown]
# -1 либо заменить (например в колонках с rooms_count)
